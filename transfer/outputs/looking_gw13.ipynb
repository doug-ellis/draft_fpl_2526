# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from other_funcs import *

# %%
df = pd.read_csv('predicted_gw13_simple.csv')
df_sorted = df.sort_values('predicted_points', ascending=False)

# %%
df_sorted.query('owner==88376.0')
# Out:
#               full_name position            team  ewma_total_points  \
# 207      erling_haaland      FWD        Man City               5.25
# 594    pedro_lomba_neto      MID         Chelsea               7.00
# 182        eberechi_eze      MID         Arsenal               9.00
# 736      yankuba_minteh      MID        Brighton               7.00
# 597          phil_foden      MID        Man City               2.50
# 177  dominik_szoboszlai      MID       Liverpool               3.75
# 371     jordan_pickford       GK         Everton               5.00
# 179      dorde_petrovic       GK     Bournemouth               3.00
# 324  jan_paul_van_hecke      DEF        Brighton               4.00
# 558       nico_o'reilly      DEF        Man City               5.25
# 124      chris_richards      DEF  Crystal Palace               5.50
# 445         lucas_digne      DEF     Aston Villa               4.25
# 568       nordi_mukiele      DEF      Sunderland               2.75
# 717     viktor_gyokeres      FWD         Arsenal               2.25
# 28       alexander_isak      FWD       Liverpool               0.50
#
#      predicted_points    owner
# 207          4.420349  88376.0
# 594          4.406814  88376.0
# 182          4.343199  88376.0
# 736          4.281271  88376.0
# 597          3.778618  88376.0
# 177          3.752292  88376.0
# 371          3.271982  88376.0
# 179          2.928286  88376.0
# 324          2.801569  88376.0
# 558          2.771905  88376.0
# 124          2.618999  88376.0
# 445          2.526943  88376.0
# 568          2.404759  88376.0
# 717          2.093583  88376.0
# 28           1.021231  88376.0

# %%
owner_dict = get_owner_dict()
df_sorted['owner'] = df_sorted['owner'].map(owner_dict)
df_sorted['owner'] = df_sorted['owner'].fillna('no_owner')

# %%
transfer_df = df_sorted.query('owner in ["no_owner", "Doug"]')

# %%
transfer_df.query('position=="GK"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                       full_name position           team  ewma_total_points  \
# 371             jordan_pickford       GK        Everton               5.00
# 179              dorde_petrovic       GK    Bournemouth               3.00
# 69              bart_verbruggen       GK       Brighton               5.00
# 83                   bernd_leno       GK         Fulham               4.00
# 511                   matz_sels       GK  Nott'm Forest               3.25
# 32              alphonse_areola       GK       West Ham               4.00
# 488             martin_dubravka       GK        Burnley               2.00
# 554                   nick_pope       GK      Newcastle               3.00
# 446         lucas_estella_perri       GK          Leeds               1.50
# 644               sam_johnstone       GK         Wolves               1.75
# 246        giorgi_mamardashvili       GK      Liverpool               4.00
# 403  kepa_arrizabalaga_revuelta       GK        Arsenal               0.00
# 399                   karl_hein       GK        Arsenal               0.00
# 697               tommy_setford       GK        Arsenal               0.00
# 2                aaron_ramsdale       GK      Newcastle               0.00
# 524                mike_penders       GK        Chelsea               0.00
# 477                 marco_bizot       GK    Aston Villa               0.00
# 645                 sam_proctor       GK    Aston Villa               0.00
# 228             filip_marschall       GK    Aston Villa               0.00
# 227             filip_jorgensen       GK        Chelsea               0.00
#
#      predicted_points     owner
# 371          3.271982      Doug
# 179          2.928286      Doug
# 69           3.274916  no_owner
# 83           3.255275  no_owner
# 511          3.214571  no_owner
# 32           2.813550  no_owner
# 488          2.776743  no_owner
# 554          2.776138  no_owner
# 446          2.728934  no_owner
# 644          2.700430  no_owner
# 246          2.229547  no_owner
# 403          0.261584  no_owner
# 399          0.261584  no_owner
# 697          0.261584  no_owner
# 2            0.254067  no_owner
# 524          0.253186  no_owner
# 477          0.253186  no_owner
# 645          0.253186  no_owner
# 228          0.253186  no_owner
# 227          0.253186  no_owner

# %%
transfer_df.query('position=="DEF"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                     full_name position            team  ewma_total_points  \
# 324        jan_paul_van_hecke      DEF        Brighton               4.00
# 558             nico_o'reilly      DEF        Man City               5.25
# 124            chris_richards      DEF  Crystal Palace               5.50
# 445               lucas_digne      DEF     Aston Villa               4.25
# 568             nordi_mukiele      DEF      Sunderland               2.75
# 561             nicolo_savona      DEF   Nott'm Forest               5.50
# 550             neco_williams      DEF   Nott'm Forest               4.25
# 402                kenny_tete      DEF          Fulham               4.25
# 538  murillo_costa_dos_santos      DEF   Nott'm Forest               5.50
# 520            michael_kayode      DEF       Brentford               1.75
# 108             calvin_bassey      DEF          Fulham               4.50
# 509          matthijs_de_ligt      DEF         Man Utd               3.25
# 357                 joe_rodon      DEF           Leeds               4.50
# 226            ferdi_kadioglu      DEF        Brighton               3.25
# 601       quilindschy_hartman      DEF         Burnley               2.50
# 217          ezri_konsa_ngoyo      DEF     Aston Villa               4.25
# 147            daniel_ballard      DEF      Sunderland               4.25
# 459                 luke_shaw      DEF         Man Utd               3.25
# 719         vitalii_mykolenko      DEF         Everton               4.50
# 592                pau_torres      DEF     Aston Villa               4.75
#
#      predicted_points     owner
# 324          2.801569      Doug
# 558          2.771905      Doug
# 124          2.618999      Doug
# 445          2.526943      Doug
# 568          2.404759      Doug
# 561          2.931698  no_owner
# 550          2.879314  no_owner
# 402          2.867332  no_owner
# 538          2.711882  no_owner
# 520          2.701425  no_owner
# 108          2.687256  no_owner
# 509          2.661156  no_owner
# 357          2.659975  no_owner
# 226          2.640000  no_owner
# 601          2.632946  no_owner
# 217          2.628512  no_owner
# 147          2.621581  no_owner
# 459          2.610140  no_owner
# 719          2.596976  no_owner
# 592          2.531108  no_owner

# %%
transfer_df.query('position=="MID"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                            full_name position           team  \
# 594                 pedro_lomba_neto      MID        Chelsea
# 182                     eberechi_eze      MID        Arsenal
# 736                   yankuba_minteh      MID       Brighton
# 597                       phil_foden      MID       Man City
# 177               dominik_szoboszlai      MID      Liverpool
# 482                 marcus_tavernier      MID    Bournemouth
# 168             diego_gomez_amarilla      MID       Brighton
# 34                       amad_diallo      MID        Man Utd
# 97   bruno_guimaraes_rodriguez_moura      MID      Newcastle
# 191                  elliot_anderson      MID  Nott'm Forest
# 93                  brenden_aaronson      MID          Leeds
# 410            kiernan_dewsbury_hall      MID        Everton
# 22                        alex_iwobi      MID         Fulham
# 114         carlos_henrique_casimiro      MID        Man Utd
# 267                    harvey_barnes      MID      Newcastle
# 639                   ryan_sessegnon      MID         Fulham
# 503                     mats_wieffer      MID       Brighton
# 249                     granit_xhaka      MID     Sunderland
# 649                     sander_berge      MID         Fulham
# 607                     rayan_cherki      MID       Man City
#
#      ewma_total_points  predicted_points     owner
# 594               7.00          4.406814      Doug
# 182               9.00          4.343199      Doug
# 736               7.00          4.281271      Doug
# 597               2.50          3.778618      Doug
# 177               3.75          3.752292      Doug
# 482               5.50          4.076535  no_owner
# 168               5.25          3.952571  no_owner
# 34                5.50          3.837412  no_owner
# 97                7.00          3.834277  no_owner
# 191               6.00          3.663164  no_owner
# 93                5.50          3.535098  no_owner
# 410               6.50          3.510389  no_owner
# 22                2.25          3.476654  no_owner
# 114               8.00          3.365380  no_owner
# 267               6.50          3.289210  no_owner
# 639               6.25          3.277372  no_owner
# 503               5.25          3.273956  no_owner
# 249               4.25          3.159631  no_owner
# 649               3.00          3.143041  no_owner
# 607               4.75          3.095055  no_owner

# %%
transfer_df.query('position=="FWD"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                             full_name position           team  \
# 207                    erling_haaland      FWD       Man City
# 717                   viktor_gyokeres      FWD        Arsenal
# 28                     alexander_isak      FWD      Liverpool
# 754                     zian_flemming      FWD        Burnley
# 107                     callum_wilson      FWD       West Ham
# 732                     wilson_isidor      FWD     Sunderland
# 278         igor_jesus_maciel_da_cruz      FWD  Nott'm Forest
# 455                      lukas_nmecha      FWD          Leeds
# 603                 randal_kolo_muani      FWD          Spurs
# 682                     thierno_barry      FWD        Everton
# 174             dominic_calvert_lewin      FWD          Leeds
# 439                        liam_delap      FWD        Chelsea
# 95                      brian_brobbey      FWD     Sunderland
# 566  norberto_bercique_gomes_betuncal      FWD        Everton
# 476                     marc_guiu_paz      FWD        Chelsea
# 382                    joshua_zirkzee      FWD        Man Utd
# 677                     taiwo_awoniyi      FWD  Nott'm Forest
# 689                    tolu_arokodare      FWD         Wolves
# 461                       lyle_foster      FWD        Burnley
# 117             charalampos_kostoulas      FWD       Brighton
#
#      ewma_total_points  predicted_points     owner
# 207               5.25          4.420349      Doug
# 717               2.25          2.093583      Doug
# 28                0.50          1.021231      Doug
# 754               5.25          4.029955  no_owner
# 107               5.75          3.646007  no_owner
# 732               3.25          3.113612  no_owner
# 278               2.25          2.919011  no_owner
# 455               4.50          2.587967  no_owner
# 603               1.50          2.337036  no_owner
# 682               1.25          2.333045  no_owner
# 174               1.50          2.014157  no_owner
# 439               1.00          1.662243  no_owner
# 95                2.75          1.595755  no_owner
# 566               1.25          1.567816  no_owner
# 476               1.75          1.473811  no_owner
# 382               0.75          1.457693  no_owner
# 677               0.75          1.356280  no_owner
# 689               0.75          1.354254  no_owner
# 461               2.00          1.146683  no_owner
# 117               1.75          1.127255  no_owner

# %%
df_sorted.query('position=="MID"').head(50)
# Out:
#                             full_name position            team  \
# 204                    enzo_fernandez      MID         Chelsea
# 533                     mohamed_salah      MID       Liverpool
# 99                       bryan_mbeumo      MID         Man Utd
# 594                  pedro_lomba_neto      MID         Chelsea
# 182                      eberechi_eze      MID         Arsenal
# 736                    yankuba_minteh      MID        Brighton
# 162                       declan_rice      MID         Arsenal
# 100                       bukayo_saka      MID         Arsenal
# 536                morgan_gibbs_white      MID   Nott'm Forest
# 425                  leandro_trossard      MID         Arsenal
# 482                  marcus_tavernier      MID     Bournemouth
# 96             bruno_borges_fernandes      MID         Man Utd
# 168              diego_gomez_amarilla      MID        Brighton
# 34                        amad_diallo      MID         Man Utd
# 97    bruno_guimaraes_rodriguez_moura      MID       Newcastle
# 597                        phil_foden      MID        Man City
# 537                     morgan_rogers      MID     Aston Villa
# 177                dominik_szoboszlai      MID       Liverpool
# 342                       jeremy_doku      MID        Man City
# 406                      kevin_schade      MID       Brentford
# 300                      jacob_murphy      MID       Newcastle
# 191                   elliot_anderson      MID   Nott'm Forest
# 145                    dango_ouattara      MID       Brentford
# 20        alejandro_garnacho_ferreyra      MID         Chelsea
# 93                   brenden_aaronson      MID           Leeds
# 410             kiernan_dewsbury_hall      MID         Everton
# 22                         alex_iwobi      MID          Fulham
# 114          carlos_henrique_casimiro      MID         Man Utd
# 267                     harvey_barnes      MID       Newcastle
# 639                    ryan_sessegnon      MID          Fulham
# 503                      mats_wieffer      MID        Brighton
# 294                     jack_grealish      MID         Everton
# 249                      granit_xhaka      MID      Sunderland
# 649                      sander_berge      MID          Fulham
# 289                      ismaila_sarr      MID  Crystal Palace
# 607                      rayan_cherki      MID        Man City
# 205                       enzo_le_fee      MID      Sunderland
# 491           martin_zubimendi_ibanez      MID         Arsenal
# 282                     iliman_ndiaye      MID         Everton
# 740                yeremy_pino_santos      MID  Crystal Palace
# 377                       josh_cullen      MID         Burnley
# 132                        cody_gakpo      MID       Liverpool
# 311                      james_garner      MID         Everton
# 29                alexis_mac_allister      MID       Liverpool
# 142                         dan_ndoye      MID   Nott'm Forest
# 705                       tyler_adams      MID     Bournemouth
# 737                       yasin_ayari      MID        Brighton
# 304                    jaidon_anthony      MID         Burnley
# 528                  mikkel_damsgaard      MID       Brentford
# 496  mateus_goncalo_espanha_fernandes      MID        West Ham
#
#      ewma_total_points  predicted_points     owner
# 204               4.50          4.818975     Lucas
# 533               5.00          4.647211    Marcus
# 99                6.25          4.531974    Marcus
# 594               7.00          4.406814      Doug
# 182               9.00          4.343199      Doug
# 736               7.00          4.281271      Doug
# 162               7.00          4.158668      Rory
# 100               5.50          4.146290      Will
# 536               7.00          4.126215     Lucas
# 425               7.50          4.082512      Dave
# 482               5.50          4.076535  no_owner
# 96                4.00          4.022371      Will
# 168               5.25          3.952571  no_owner
# 34                5.50          3.837412  no_owner
# 97                7.00          3.834277  no_owner
# 597               2.50          3.778618      Doug
# 537               5.25          3.773985    Marcus
# 177               3.75          3.752292      Doug
# 342               4.00          3.731306     Lucas
# 406               4.50          3.721091      Will
# 300               5.00          3.663971      Dave
# 191               6.00          3.663164  no_owner
# 145               5.50          3.621478      Dave
# 20                5.00          3.613689    Marcus
# 93                5.50          3.535098  no_owner
# 410               6.50          3.510389  no_owner
# 22                2.25          3.476654  no_owner
# 114               8.00          3.365380  no_owner
# 267               6.50          3.289210  no_owner
# 639               6.25          3.277372  no_owner
# 503               5.25          3.273956  no_owner
# 294               2.25          3.191109      Dave
# 249               4.25          3.159631  no_owner
# 649               3.00          3.143041  no_owner
# 289               2.75          3.123635      Dave
# 607               4.75          3.095055  no_owner
# 205               2.75          3.043847  no_owner
# 491               3.75          3.040964  no_owner
# 282               4.25          3.023962      Will
# 740               3.25          3.006547  no_owner
# 377               3.75          2.996904  no_owner
# 132               2.00          2.925703     Lucas
# 311               3.00          2.901662  no_owner
# 29                2.50          2.885196  no_owner
# 142               2.75          2.871072  no_owner
# 705               4.50          2.857875  no_owner
# 737               2.75          2.852564  no_owner
# 304               2.00          2.848356  no_owner
# 528               3.25          2.846605  no_owner
# 496               4.50          2.828689  no_owner

# %%
a, b = get_best_11(df_sorted.query('owner=="Doug" and ~full_name.str.contains("reilly")'))
b
# Out:
#              full_name position            team  ewma_total_points  \
# 10      erling_haaland      FWD        Man City               5.25
# 5     pedro_lomba_neto      MID         Chelsea               7.00
# 6         eberechi_eze      MID         Arsenal               9.00
# 7       yankuba_minteh      MID        Brighton               7.00
# 8           phil_foden      MID        Man City               2.50
# 9   dominik_szoboszlai      MID       Liverpool               3.75
# 0      jordan_pickford       GK         Everton               5.00
# 1   jan_paul_van_hecke      DEF        Brighton               4.00
# 2       chris_richards      DEF  Crystal Palace               5.50
# 3          lucas_digne      DEF     Aston Villa               4.25
# 4        nordi_mukiele      DEF      Sunderland               2.75
#
#     predicted_points owner
# 10          4.420349  Doug
# 5           4.406814  Doug
# 6           4.343199  Doug
# 7           4.281271  Doug
# 8           3.778618  Doug
# 9           3.752292  Doug
# 0           3.271982  Doug
# 1           2.801569  Doug
# 2           2.618999  Doug
# 3           2.526943  Doug
# 4           2.404759  Doug

# %% [markdown]
# # Random stuff

# %%
sns.kdeplot(data=df_sorted, x='predicted_points', hue='position')
# Out:
# <Axes: xlabel='predicted_points', ylabel='Density'>

# %%
check_pred_vs_avg = df_sorted.melt(id_vars=['full_name', 'position'], value_vars=['predicted_points', 'ewma_total_points'])
sns.kdeplot(data=check_pred_vs_avg.query('position=="DEF"'), x='value', hue='variable')
# Out:
# <Axes: xlabel='value', ylabel='Density'>

# %%
a, b, = get_best_11(df_sorted)
b
# Out:
#                            full_name position            team  \
# 4                     enzo_fernandez      MID         Chelsea
# 5                      mohamed_salah      MID       Liverpool
# 6                       bryan_mbeumo      MID         Man Utd
# 8                      danny_welbeck      FWD        Brighton
# 9                     erling_haaland      FWD        Man City
# 7                   pedro_lomba_neto      MID         Chelsea
# 10  igor_thiago_nascimento_rodrigues      FWD       Brentford
# 0                     dean_henderson       GK  Crystal Palace
# 1              marc_cucurella_saseta      DEF         Chelsea
# 2                         matty_cash      DEF     Aston Villa
# 3                    tyrick_mitchell      DEF  Crystal Palace
#
#     ewma_total_points  predicted_points   owner
# 4                4.50          4.818975   Lucas
# 5                5.00          4.647211  Marcus
# 6                6.25          4.531974  Marcus
# 8                5.50          4.473093   Lucas
# 9                5.25          4.420349    Doug
# 7                7.00          4.406814    Doug
# 10               6.00          4.385580  Marcus
# 0                5.75          3.653622    Will
# 1                5.00          3.344401    Will
# 2                5.75          3.078130    Dave
# 3                6.25          2.963650    Dave

# %%
owner_dict = get_owner_dict()
b['owner'] = b['owner'].map(owner_dict)

# %%
b = b.sort_values('position', key=lambda s: s.apply(['GK', 'DEF', 'MID', 'FWD'].index), ignore_index=True)
b[['full_name', 'position', 'team', 'owner']]
# Out:
#                            full_name position            team owner
# 0                     dean_henderson       GK  Crystal Palace   NaN
# 1                    tyrick_mitchell      DEF  Crystal Palace   NaN
# 2                         matty_cash      DEF     Aston Villa   NaN
# 3              marc_cucurella_saseta      DEF         Chelsea   NaN
# 4                   pedro_lomba_neto      MID         Chelsea   NaN
# 5                     enzo_fernandez      MID         Chelsea   NaN
# 6                       bryan_mbeumo      MID         Man Utd   NaN
# 7                      mohamed_salah      MID       Liverpool   NaN
# 8   igor_thiago_nascimento_rodrigues      FWD       Brentford   NaN
# 9                     erling_haaland      FWD        Man City   NaN
# 10                     danny_welbeck      FWD        Brighton   NaN

# %%
df_sorted.query('owner!="no_owner"').sort_values('predicted_points').head(40)
# Out:
#                                full_name position            team  \
# 489                      martin_odegaard      MID         Arsenal
# 133                          cole_palmer      MID         Chelsea
# 742                          yoane_wissa      FWD       Newcastle
# 31                        alisson_becker       GK       Liverpool
# 28                        alexander_isak      FWD       Liverpool
# 599                       piero_hincapie      DEF         Arsenal
# 141                             dan_burn      DEF       Newcastle
# 49                        anthony_gordon      MID       Newcastle
# 595                  pedro_porro_sauceda      DEF           Spurs
# 276                      ibrahima_konate      DEF       Liverpool
# 717                      viktor_gyokeres      FWD         Arsenal
# 608                          reece_james      DEF         Chelsea
# 475                           marc_guehi      DEF  Crystal Palace
# 79                        benjamin_sesko      FWD         Man Utd
# 231  francisco_evanilson_de_lima_barbosa      FWD     Bournemouth
# 637                     ryan_gravenberch      MID       Liverpool
# 730                       william_saliba      DEF         Arsenal
# 568                        nordi_mukiele      DEF      Sunderland
# 718                      virgil_van_dijk      DEF       Liverpool
# 383                       josko_gvardiol      DEF        Man City
# 535                moises_caicedo_corozo      MID         Chelsea
# 236         gabriel_dos_santos_magalhaes      DEF         Arsenal
# 51                       antoine_semenyo      MID     Bournemouth
# 445                          lucas_digne      DEF     Aston Villa
# 478                  marcos_senesi_baron      DEF     Bournemouth
# 124                       chris_richards      DEF  Crystal Palace
# 271                         hugo_ekitike      FWD       Liverpool
# 500     matheus_santos_carneiro_da_cunha      MID         Man Utd
# 389                        junior_kroupi      FWD     Bournemouth
# 523                     micky_van_de_ven      DEF           Spurs
# 702                      trevoh_chalobah      DEF         Chelsea
# 499                        matheus_nunes      DEF        Man City
# 558                        nico_o'reilly      DEF        Man City
# 521                        michael_keane      DEF         Everton
# 615                   riccardo_calafiori      DEF         Arsenal
# 14                       adrien_truffert      DEF     Bournemouth
# 635     ruben_dos_santos_gato_alves_dias      DEF        Man City
# 324                   jan_paul_van_hecke      DEF        Brighton
# 319                      james_tarkowski      DEF         Everton
# 514                      maxence_lacroix      DEF  Crystal Palace
#
#      ewma_total_points  predicted_points   owner
# 489               0.00          0.367508  Marcus
# 133               0.00          0.367508    Rory
# 742               0.00          0.464987    Dave
# 31                0.50          0.827836    Will
# 28                0.50          1.021231    Doug
# 599               1.00          1.053726    Rory
# 141               0.75          1.355859    Dave
# 49                0.75          1.411552    Rory
# 595               3.75          1.898305    Will
# 276               3.00          2.051601   Lucas
# 717               2.25          2.093583    Doug
# 608               2.50          2.149091    Rory
# 475               4.75          2.186270  Marcus
# 79                1.75          2.190471    Will
# 231               2.00          2.207553   Lucas
# 637               3.50          2.235563    Rory
# 730               2.50          2.267173   Lucas
# 568               2.75          2.404759    Doug
# 718               3.00          2.411982  Marcus
# 383               2.75          2.434271   Lucas
# 535               3.50          2.480957    Rory
# 236               5.50          2.496101    Will
# 51                1.25          2.496728    Will
# 445               4.25          2.526943    Doug
# 478               3.25          2.594926    Rory
# 124               5.50          2.618999    Doug
# 271               1.50          2.636291   Lucas
# 500               3.75          2.709980   Lucas
# 389               1.50          2.731290    Dave
# 523               6.50          2.731330    Rory
# 702               5.00          2.745643   Lucas
# 499               4.50          2.763122    Dave
# 558               5.25          2.771905    Doug
# 521               7.25          2.778676    Dave
# 615               3.75          2.786520   Lucas
# 14                3.00          2.796456  Marcus
# 635               4.75          2.798887  Marcus
# 324               4.00          2.801569    Doug
# 319               4.00          2.804078  Marcus
# 514               7.25          2.902728    Rory

# %%
pred_points
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pred_points
#
# NameError: name 'pred_points' is not defined

# %%
lw_results = pd.DataFrame({'User': ['Doug', 'Lucas', 'Will', 'Marcus', 'Dave', 'Rory'],
              'Predicted points': pred_points,
              'Actual points': [33, 13, 39, 36, 30, 42]}, 
              )

# %%
lw_results.sort_values('Actual points', ascending=False)
# Out:
#      User  Predicted points  Actual points
# 5    Rory             33.34             42
# 2    Will             40.75             39
# 3  Marcus             32.91             36
# 0    Doug             39.28             33
# 4    Dave             36.83             30
# 1   Lucas             36.82             13

# %%
plt.figure(figsize=(3,3))
ax = sns.scatterplot(data=lw_results, x='Predicted points', y='Actual points', hue='User', s=100)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# # Figuring out how the model did last week

# %%
gw6 = pd.read_csv('predicted_gw6_simple.csv')
gw6
# Out:
#                 full_name position         team  ewma_total_points  \
# 0         aaron_anselmino      DEF      Chelsea             0.0000
# 1            aaron_hickey      DEF    Brentford             0.3129
# 2          aaron_ramsdale       GK    Newcastle             0.0000
# 3            aaron_ramsey      MID      Burnley             0.0000
# 4       aaron_wan_bissaka      DEF     West Ham             0.2401
# ..                    ...      ...          ...                ...
# 736  zain_silcott_duberry      MID  Bournemouth             0.0000
# 737           zak_johnson      DEF   Sunderland             0.0000
# 738          zeki_amdouni      FWD      Burnley             0.0000
# 739     zepiqueno_redmond      FWD  Aston Villa             0.0000
# 740         zian_flemming      FWD      Burnley             0.6430
#
#      predicted_points  owner
# 0            0.108120    NaN
# 1            0.214515    NaN
# 2            0.061611    NaN
# 3            0.178312    NaN
# 4            0.729524    NaN
# ..                ...    ...
# 736          0.263160    NaN
# 737          0.122112    NaN
# 738          0.067864    NaN
# 739          0.236978    NaN
# 740          0.862229    NaN
#
# [741 rows x 6 columns]

# %%
gw7 = pd.read_csv('predicted_gw7.csv')
gw6_7_merged = gw6.merge(gw7[['full_name', 'total_points']], on='full_name')

# %%
import numpy as np
import scipy
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error

# %%
x = gw6_7_merged['predicted_points']
y = gw6_7_merged['total_points']
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print(r_value)
# Out:
# 0.5529193700354283

# %%
sns.scatterplot(data=gw6_7_merged, x='predicted_points', y='total_points', hue='position')
x_range = np.linspace(0,6, 100)
y_range = slope*x_range + intercept
# plt.plot(x_range, y_range, color='black')

# %%
sns.scatterplot(data=gw6_7_merged, x='ewma_total_points', y='total_points', hue='position')
# Out:
# <Axes: xlabel='ewma_total_points', ylabel='total_points'>

# %%
root_mean_squared_error(x, y)
# Out:
# 1.8981549268092774
