# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from other_funcs import *

# %%
df = pd.read_csv('predicted_gw23_simple.csv')
df_sorted = df.sort_values('predicted_points', ascending=False)

# %%
df_sorted.query('owner==88376.0')
# Out:
#                             full_name position        team  ewma_total_points  \
# 217                    erling_haaland      FWD    Man City           1.074713
# 328                      james_garner      MID     Everton           3.696537
# 629                        phil_foden      MID    Man City           0.492086
# 573                    nathan_collins      DEF   Brentford           4.133508
# 526  matheus_santos_carneiro_da_cunha      MID     Man Utd           1.802998
# 622                     patrick_dorgu      DEF     Man Utd           2.676939
# 390                   jordan_pickford       GK     Everton           2.822596
# 626                  pedro_lomba_neto      MID     Chelsea           0.929056
# 627               pedro_porro_sauceda      DEF       Spurs           1.948655
# 597                     nordi_mukiele      DEF  Sunderland           2.822596
# 71                    bart_verbruggen       GK    Brighton           1.220370
# 760                   viktor_gyokeres      FWD     Arsenal           0.346429
# 54                        anton_stach      MID       Leeds           0.929056
# 587                     nico_o'reilly      DEF    Man City          -0.236199
# 28                     alexander_isak      FWD   Liverpool          -0.673169
#
#      predicted_points    owner
# 217          5.579102  88376.0
# 328          4.742776  88376.0
# 629          4.207820  88376.0
# 573          4.078149  88376.0
# 526          4.062068  88376.0
# 622          3.985365  88376.0
# 390          3.957191  88376.0
# 626          3.841899  88376.0
# 627          3.829363  88376.0
# 597          3.633388  88376.0
# 71           3.621572  88376.0
# 760          3.344948  88376.0
# 54           3.249522  88376.0
# 587          2.014083  88376.0
# 28           1.775879  88376.0

# %%
owner_dict = get_owner_dict()
df_sorted['owner'] = df_sorted['owner'].map(owner_dict)
df_sorted['owner'] = df_sorted['owner'].fillna('no_owner')

# %%
transfer_df = df_sorted.query('owner in ["no_owner", "Doug"]')

# %%
transfer_df.query('position=="GK"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                       full_name position            team  ewma_total_points  \
# 390             jordan_pickford       GK         Everton           2.822596
# 71              bart_verbruggen       GK        Brighton           1.220370
# 394         jose_malheiro_de_sa       GK          Wolves           1.948655
# 171              dean_henderson       GK  Crystal Palace           1.366027
# 514             martin_dubravka       GK         Burnley           0.929056
# 87                   bernd_leno       GK          Fulham           0.637743
# 33              alphonse_areola       GK        West Ham           0.637743
# 207    emiliano_martinez_romero       GK     Aston Villa           0.346429
# 469         lucas_estella_perri       GK           Leeds           1.220370
# 537                   matz_sels       GK   Nott'm Forest           1.366027
# 386  john_victor_maciel_furtado       GK   Nott'm Forest          -0.381856
# 417                 karl_darlow       GK           Leeds           0.200772
# 238             filip_jorgensen       GK         Chelsea          -0.381856
# 502                 marco_bizot       GK     Aston Villa          -0.381856
# 2                aaron_ramsdale       GK       Newcastle          -0.673169
# 600        odysseas_vlachodimos       GK       Newcastle          -0.673169
# 384                  john_ruddy       GK       Newcastle          -0.673169
# 423  kepa_arrizabalaga_revuelta       GK         Arsenal          -0.673169
# 508              mark_gillespie       GK       Newcastle          -0.673169
# 737               tommy_setford       GK         Arsenal          -0.673169
#
#      predicted_points     owner
# 390          3.957191      Doug
# 71           3.621572      Doug
# 394          3.717909  no_owner
# 171          3.579386  no_owner
# 514          3.392310  no_owner
# 87           3.386211  no_owner
# 33           3.216149  no_owner
# 207          2.904679  no_owner
# 469          2.832078  no_owner
# 537          2.288015  no_owner
# 386          1.651044  no_owner
# 417          1.458652  no_owner
# 238          1.300117  no_owner
# 502          1.026716  no_owner
# 2            0.807645  no_owner
# 600          0.747446  no_owner
# 384          0.747446  no_owner
# 423          0.747395  no_owner
# 508          0.746570  no_owner
# 737          0.745643  no_owner

# %%
transfer_df.query('position=="DEF"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                       full_name position           team  ewma_total_points  \
# 573              nathan_collins      DEF      Brentford           4.133508
# 622               patrick_dorgu      DEF        Man Utd           2.676939
# 627         pedro_porro_sauceda      DEF          Spurs           1.948655
# 597               nordi_mukiele      DEF     Sunderland           2.822596
# 587               nico_o'reilly      DEF       Man City          -0.236199
# 287            hugo_bueno_lopez      DEF         Wolves           2.822596
# 785  yerson_mosquera_valdelamar      DEF         Wolves           2.385625
# 579               neco_williams      DEF  Nott'm Forest           1.074713
# 324                jake_o'brien      DEF        Everton           2.094312
# 620              pascal_struijk      DEF          Leeds           2.822596
# 341          jan_paul_van_hecke      DEF       Brighton           1.511684
# 483                   luke_shaw      DEF        Man Utd           0.783400
# 440             ladislav_krejci      DEF         Wolves           2.531282
# 548              michael_kayode      DEF      Brentford           1.220370
# 181        diogo_dalot_teixeira      DEF        Man Utd           0.783400
# 463           lisandro_martinez      DEF        Man Utd           1.511684
# 558                milos_kerkez      DEF      Liverpool           1.074713
# 436             kristoffer_ajer      DEF      Brentford           2.094312
# 55             antonee_robinson      DEF         Fulham           0.346429
# 567    murillo_costa_dos_santos      DEF  Nott'm Forest           1.366027
#
#      predicted_points     owner
# 573          4.078149      Doug
# 622          3.985365      Doug
# 627          3.829363      Doug
# 597          3.633388      Doug
# 587          2.014083      Doug
# 287          3.609643  no_owner
# 785          3.334146  no_owner
# 579          3.292605  no_owner
# 324          3.212997  no_owner
# 620          3.165276  no_owner
# 341          3.116009  no_owner
# 483          3.089647  no_owner
# 440          3.079323  no_owner
# 548          3.075094  no_owner
# 181          3.051195  no_owner
# 463          3.023400  no_owner
# 558          3.018674  no_owner
# 436          2.983609  no_owner
# 55           2.962511  no_owner
# 567          2.949658  no_owner

# %%
transfer_df.query('position=="MID"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                                full_name position            team  \
# 328                         james_garner      MID         Everton
# 629                           phil_foden      MID        Man City
# 526     matheus_santos_carneiro_da_cunha      MID         Man Utd
# 626                     pedro_lomba_neto      MID         Chelsea
# 54                           anton_stach      MID           Leeds
# 382  joelinton_cassio_apolinario_de_lira      MID       Newcastle
# 784                   yeremy_pino_santos      MID  Crystal Palace
# 98                      brenden_aaronson      MID           Leeds
# 119             carlos_henrique_casimiro      MID         Man Utd
# 763                        vitaly_janelt      MID       Brentford
# 187                   dominik_szoboszlai      MID       Liverpool
# 787                      youri_tielemans      MID     Aston Villa
# 215                          enzo_le_fee      MID      Sunderland
# 507                     marcus_tavernier      MID     Bournemouth
# 517              martin_zubimendi_ibanez      MID         Arsenal
# 143                      conor_gallagher      MID           Spurs
# 146                crysencio_summerville      MID        West Ham
# 289                       hwang_hee_chan      MID          Wolves
# 783                      yehor_yarmoliuk      MID       Brentford
# 560                         mitoma_kaoru      MID        Brighton
#
#      ewma_total_points  predicted_points     owner
# 328           3.696537          4.742776      Doug
# 629           0.492086          4.207820      Doug
# 526           1.802998          4.062068      Doug
# 626           0.929056          3.841899      Doug
# 54            0.929056          3.249522      Doug
# 382           2.822596          4.490735  no_owner
# 784           1.657341          4.406948  no_owner
# 98            3.259567          4.324930  no_owner
# 119           2.239969          4.272027  no_owner
# 763           2.822596          4.244237  no_owner
# 187           0.492086          4.103579  no_owner
# 787           1.366027          3.959081  no_owner
# 215           1.802998          3.923645  no_owner
# 507           1.948655          3.754415  no_owner
# 517           2.094312          3.682690  no_owner
# 143           0.492086          3.668167  no_owner
# 146           1.802998          3.627947  no_owner
# 289           1.802998          3.541091  no_owner
# 783           1.948655          3.537355  no_owner
# 560           1.366027          3.519262  no_owner

# %%
transfer_df.query('position=="FWD"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                          full_name position           team  ewma_total_points  \
# 217                 erling_haaland      FWD       Man City           1.074713
# 760                viktor_gyokeres      FWD        Arsenal           0.346429
# 28                  alexander_isak      FWD      Liverpool          -0.673169
# 721                  thierno_barry      FWD        Everton           2.531282
# 523                    mateus_mane      FWD         Wolves           2.968253
# 757           valentin_castellanos      FWD       West Ham           0.200772
# 61                   armando_broja      FWD        Burnley           1.220370
# 729                 tolu_arokodare      FWD         Wolves           0.492086
# 461                     liam_delap      FWD        Chelsea           1.220370
# 295      igor_jesus_maciel_da_cruz      FWD  Nott'm Forest           0.492086
# 649         richarlison_de_andrade      FWD          Spurs           0.055115
# 112                  callum_wilson      FWD       West Ham           1.220370
# 408                  junior_kroupi      FWD    Bournemouth           1.366027
# 198         eliezer_mayenda_dossou      FWD     Sunderland           0.200772
# 401                 joshua_zirkzee      FWD        Man Utd           1.220370
# 250      gabriel_fernando_de_jesus      FWD        Arsenal           0.346429
# 478                   lukas_nmecha      FWD          Leeds           0.929056
# 122          charalampos_kostoulas      FWD       Brighton           1.220370
# 616  pablo_felipe_pereira_de_jesus      FWD       West Ham          -0.090542
# 392           jorgen_strand_larsen      FWD         Wolves           0.200772
#
#      predicted_points     owner
# 217          5.579102      Doug
# 760          3.344948      Doug
# 28           1.775879      Doug
# 721          4.200978  no_owner
# 523          4.151817  no_owner
# 757          3.605496  no_owner
# 61           3.393705  no_owner
# 729          3.107359  no_owner
# 461          3.098502  no_owner
# 295          3.087287  no_owner
# 649          2.741546  no_owner
# 112          2.573426  no_owner
# 408          2.551086  no_owner
# 198          2.440229  no_owner
# 401          2.353931  no_owner
# 250          2.278763  no_owner
# 478          2.075703  no_owner
# 122          2.069596  no_owner
# 616          2.025407  no_owner
# 392          1.921452  no_owner

# %%
df_sorted.query('position=="GK"').head(50)
# Out:
#                       full_name position            team  ewma_total_points  \
# 390             jordan_pickford       GK         Everton           2.822596
# 260        gianluigi_donnarumma       GK        Man City           1.074713
# 394         jose_malheiro_de_sa       GK          Wolves           1.948655
# 169           david_raya_martin       GK         Arsenal           1.511684
# 32               alisson_becker       GK       Liverpool           2.094312
# 583                   nick_pope       GK       Newcastle           1.657341
# 656                 robin_roefs       GK      Sunderland           1.366027
# 71              bart_verbruggen       GK        Brighton           1.220370
# 171              dean_henderson       GK  Crystal Palace           1.366027
# 697               senne_lammens       GK         Man Utd           1.074713
# 514             martin_dubravka       GK         Burnley           0.929056
# 266           guglielmo_vicario       GK           Spurs           0.637743
# 87                   bernd_leno       GK          Fulham           0.637743
# 115           caoimhin_kelleher       GK       Brentford           2.531282
# 33              alphonse_areola       GK        West Ham           0.637743
# 189              dorde_petrovic       GK     Bournemouth           0.055115
# 655        robert_lynch_sanchez       GK         Chelsea           1.511684
# 207    emiliano_martinez_romero       GK     Aston Villa           0.346429
# 469         lucas_estella_perri       GK           Leeds           1.220370
# 537                   matz_sels       GK   Nott'm Forest           1.366027
# 386  john_victor_maciel_furtado       GK   Nott'm Forest          -0.381856
# 417                 karl_darlow       GK           Leeds           0.200772
# 238             filip_jorgensen       GK         Chelsea          -0.381856
# 502                 marco_bizot       GK     Aston Villa          -0.381856
# 2                aaron_ramsdale       GK       Newcastle          -0.673169
# 600        odysseas_vlachodimos       GK       Newcastle          -0.673169
# 384                  john_ruddy       GK       Newcastle          -0.673169
# 423  kepa_arrizabalaga_revuelta       GK         Arsenal          -0.673169
# 508              mark_gillespie       GK       Newcastle          -0.673169
# 737               tommy_setford       GK         Arsenal          -0.673169
# 418                   karl_hein       GK         Arsenal          -0.673169
# 509                mark_travers       GK         Everton          -0.673169
# 404             julian_eyestone       GK       Brentford          -0.673169
# 534                 matthew_cox       GK       Brentford          -0.673169
# 200             ellery_balcombe       GK       Brentford          -0.673169
# 270     hakon_rafn_valdimarsson       GK       Brentford          -0.673169
# 282                 harry_tyrer       GK         Everton          -0.673169
# 733                    tom_king       GK         Everton          -0.673169
# 41                  andre_onana       GK         Man Utd          -0.673169
# 681               sam_johnstone       GK          Wolves          -0.673169
# 34               altay_bayindir       GK         Man Utd          -0.673169
# 432              kjell_scherpen       GK        Brighton          -0.673169
# 202               elyh_harrison       GK         Man Utd          -0.673169
# 116              carl_rushworth       GK        Brighton          -0.673169
# 156              daniel_bentley       GK          Wolves          -0.673169
# 344                jason_steele       GK        Brighton          -0.673169
# 734                  tom_mcgill       GK        Brighton          -0.673169
# 175                  dermot_mee       GK         Man Utd          -0.673169
# 732                  tom_heaton       GK         Man Utd          -0.673169
# 540                 max_merrick       GK         Chelsea          -0.673169
#
#      predicted_points     owner
# 390          3.957191      Doug
# 260          3.755126     Lucas
# 394          3.717909  no_owner
# 169          3.702144      Dave
# 32           3.674573      Will
# 583          3.654566     Lucas
# 656          3.622401      Rory
# 71           3.621572      Doug
# 171          3.579386  no_owner
# 697          3.393832      Rory
# 514          3.392310  no_owner
# 266          3.391512    Marcus
# 87           3.386211  no_owner
# 115          3.217483      Dave
# 33           3.216149  no_owner
# 189          3.076194      Will
# 655          2.987946    Marcus
# 207          2.904679  no_owner
# 469          2.832078  no_owner
# 537          2.288015  no_owner
# 386          1.651044  no_owner
# 417          1.458652  no_owner
# 238          1.300117  no_owner
# 502          1.026716  no_owner
# 2            0.807645  no_owner
# 600          0.747446  no_owner
# 384          0.747446  no_owner
# 423          0.747395  no_owner
# 508          0.746570  no_owner
# 737          0.745643  no_owner
# 418          0.703225  no_owner
# 509          0.683743  no_owner
# 404          0.682093  no_owner
# 534          0.682093  no_owner
# 200          0.682093  no_owner
# 270          0.682093  no_owner
# 282          0.680239  no_owner
# 733          0.680239  no_owner
# 41           0.668744  no_owner
# 681          0.666220  no_owner
# 34           0.661464  no_owner
# 432          0.660859  no_owner
# 202          0.660859  no_owner
# 116          0.660859  no_owner
# 156          0.658128  no_owner
# 344          0.656426  no_owner
# 734          0.653798  no_owner
# 175          0.653798  no_owner
# 732          0.653798  no_owner
# 540          0.653797  no_owner

# %%
df_sorted.query('position=="DEF"').head(50)
# Out:
#                         full_name position            team  ewma_total_points  \
# 573                nathan_collins      DEF       Brentford           4.133508
# 249  gabriel_dos_santos_magalhaes      DEF         Arsenal           4.861793
# 622                 patrick_dorgu      DEF         Man Utd           2.676939
# 627           pedro_porro_sauceda      DEF           Spurs           1.948655
# 336               james_tarkowski      DEF         Everton           2.676939
# 597                 nordi_mukiele      DEF      Sunderland           2.822596
# 409                jurrien_timber      DEF         Arsenal           2.676939
# 457                    lewis_hall      DEF       Newcastle           2.676939
# 287              hugo_bueno_lopez      DEF          Wolves           2.822596
# 237                ferdi_kadioglu      DEF        Brighton           1.802998
# 491                  malick_thiaw      DEF       Newcastle           3.550881
# 145               cristian_romero      DEF           Spurs           2.531282
# 785    yerson_mosquera_valdelamar      DEF          Wolves           2.385625
# 774                william_saliba      DEF         Arsenal           1.948655
# 579                 neco_williams      DEF   Nott'm Forest           1.074713
# 324                  jake_o'brien      DEF         Everton           2.094312
# 293               ibrahima_konate      DEF       Liverpool           1.802998
# 620                pascal_struijk      DEF           Leeds           2.822596
# 761               virgil_van_dijk      DEF       Liverpool           1.511684
# 762             vitalii_mykolenko      DEF         Everton           1.657341
# 341            jan_paul_van_hecke      DEF        Brighton           1.511684
# 359              jeremie_frimpong      DEF       Liverpool           1.948655
# 483                     luke_shaw      DEF         Man Utd           0.783400
# 440               ladislav_krejci      DEF          Wolves           2.531282
# 548                michael_kayode      DEF       Brentford           1.220370
# 181          diogo_dalot_teixeira      DEF         Man Utd           0.783400
# 463             lisandro_martinez      DEF         Man Utd           1.511684
# 551              micky_van_de_ven      DEF           Spurs           1.220370
# 558                  milos_kerkez      DEF       Liverpool           1.074713
# 742               trevoh_chalobah      DEF         Chelsea           1.657341
# 436               kristoffer_ajer      DEF       Brentford           2.094312
# 55               antonee_robinson      DEF          Fulham           0.346429
# 567      murillo_costa_dos_santos      DEF   Nott'm Forest           1.366027
# 330                  james_justin      DEF           Leeds           2.094312
# 525                 matheus_nunes      DEF        Man City           1.366027
# 503           marcos_senesi_baron      DEF     Bournemouth           1.220370
# 456                    lewis_dunk      DEF        Brighton           1.220370
# 542               maxence_lacroix      DEF  Crystal Palace           1.366027
# 251           gabriel_gudmundsson      DEF           Leeds           1.657341
# 753               tyrick_mitchell      DEF  Crystal Palace           0.929056
# 315            jackson_tchatchoua      DEF          Wolves           1.366027
# 72               bashir_humphreys      DEF         Burnley           1.366027
# 740                     trai_hume      DEF      Sunderland           0.637743
# 228              ezri_konsa_ngoyo      DEF     Aston Villa           0.929056
# 364              joachim_andersen      DEF          Fulham           0.783400
# 536                    matty_cash      DEF     Aston Villa           1.220370
# 591             nikola_milenkovic      DEF   Nott'm Forest           1.074713
# 606                 ollie_scarles      DEF        West Ham           0.783400
# 229                  fabian_schar      DEF       Newcastle           1.511684
# 609                 omar_alderete      DEF      Sunderland           0.929056
#
#      predicted_points     owner
# 573          4.078149      Doug
# 249          4.033749      Will
# 622          3.985365      Doug
# 627          3.829363      Doug
# 336          3.648800    Marcus
# 597          3.633388      Doug
# 409          3.629316      Will
# 457          3.628597      Will
# 287          3.609643  no_owner
# 237          3.579223     Lucas
# 491          3.414133      Dave
# 145          3.373464      Rory
# 785          3.334146  no_owner
# 774          3.322351     Lucas
# 579          3.292605  no_owner
# 324          3.212997  no_owner
# 293          3.190598     Lucas
# 620          3.165276  no_owner
# 761          3.134685    Marcus
# 762          3.124516      Rory
# 341          3.116009  no_owner
# 359          3.108337      Dave
# 483          3.089647  no_owner
# 440          3.079323  no_owner
# 548          3.075094  no_owner
# 181          3.051195  no_owner
# 463          3.023400  no_owner
# 551          3.021824      Rory
# 558          3.018674  no_owner
# 742          3.001992      Rory
# 436          2.983609  no_owner
# 55           2.962511  no_owner
# 567          2.949658  no_owner
# 330          2.916375  no_owner
# 525          2.855563     Lucas
# 503          2.836299  no_owner
# 456          2.833192  no_owner
# 542          2.826775  no_owner
# 251          2.822688  no_owner
# 753          2.813230  no_owner
# 315          2.810499  no_owner
# 72           2.790516  no_owner
# 740          2.775966  no_owner
# 228          2.775826      Will
# 364          2.729343    Marcus
# 536          2.713411      Dave
# 591          2.711507  no_owner
# 606          2.686854  no_owner
# 229          2.682595  no_owner
# 609          2.681717      Dave

# %%
df_sorted.query('position=="MID"').head(50)
# Out:
#                                    full_name position            team  \
# 102          bruno_guimaraes_rodriguez_moura      MID       Newcastle
# 241                            florian_wirtz      MID       Liverpool
# 214                           enzo_fernandez      MID         Chelsea
# 426                             kevin_schade      MID       Brentford
# 140                              cole_palmer      MID         Chelsea
# 328                             james_garner      MID         Everton
# 565                       morgan_gibbs_white      MID   Nott'm Forest
# 566                            morgan_rogers      MID     Aston Villa
# 105                              bukayo_saka      MID         Arsenal
# 283                             harry_wilson      MID          Fulham
# 382      joelinton_cassio_apolinario_de_lira      MID       Newcastle
# 515                          martin_odegaard      MID         Arsenal
# 639                             rayan_cherki      MID        Man City
# 784                       yeremy_pino_santos      MID  Crystal Palace
# 284                            harvey_barnes      MID       Newcastle
# 172                              declan_rice      MID         Arsenal
# 98                          brenden_aaronson      MID           Leeds
# 53                           antoine_semenyo      MID        Man City
# 119                 carlos_henrique_casimiro      MID         Man Utd
# 763                            vitaly_janelt      MID       Brentford
# 629                               phil_foden      MID        Man City
# 187                       dominik_szoboszlai      MID       Liverpool
# 139                               cody_gakpo      MID       Liverpool
# 526         matheus_santos_carneiro_da_cunha      MID         Man Utd
# 787                          youri_tielemans      MID     Aston Villa
# 215                              enzo_le_fee      MID      Sunderland
# 101                   bruno_borges_fernandes      MID         Man Utd
# 626                         pedro_lomba_neto      MID         Chelsea
# 51                            anthony_gordon      MID       Newcastle
# 507                         marcus_tavernier      MID     Bournemouth
# 517                  martin_zubimendi_ibanez      MID         Arsenal
# 311                            jack_grealish      MID         Everton
# 143                          conor_gallagher      MID           Spurs
# 146                    crysencio_summerville      MID        West Ham
# 289                           hwang_hee_chan      MID          Wolves
# 783                          yehor_yarmoliuk      MID       Brentford
# 560                             mitoma_kaoru      MID        Brighton
# 445                         leandro_trossard      MID         Arsenal
# 505                           marcus_edwards      MID         Burnley
# 86   bernardo_mota_veiga_de_carvalho_e_silva      MID        Man City
# 671                         ryan_gravenberch      MID       Liverpool
# 588                        nicolas_dominguez      MID   Nott'm Forest
# 11                              adam_wharton      MID  Crystal Palace
# 383                              john_mcginn      MID     Aston Villa
# 201                          elliot_anderson      MID   Nott'm Forest
# 522         mateus_goncalo_espanha_fernandes      MID        West Ham
# 191                            dwight_mcneil      MID         Everton
# 528                               mathys_tel      MID           Spurs
# 205                         emile_smith_rowe      MID          Fulham
# 265                             granit_xhaka      MID      Sunderland
#
#      ewma_total_points  predicted_points     owner
# 102           4.279165          6.121506    Marcus
# 241           3.113910          5.869388     Lucas
# 214           3.259567          5.096164     Lucas
# 426           1.657341          4.771998     Lucas
# 140           2.094312          4.762245      Rory
# 328           3.696537          4.742776      Doug
# 565           2.531282          4.707208      Dave
# 566           0.929056          4.699878    Marcus
# 105           1.366027          4.635111      Will
# 283           2.094312          4.521785      Dave
# 382           2.822596          4.490735  no_owner
# 515           1.657341          4.469783    Marcus
# 639           0.929056          4.433708      Dave
# 784           1.657341          4.406948  no_owner
# 284           2.385625          4.400243      Rory
# 172           2.676939          4.345062      Rory
# 98            3.259567          4.324930  no_owner
# 53            1.366027          4.296783      Will
# 119           2.239969          4.272027  no_owner
# 763           2.822596          4.244237  no_owner
# 629           0.492086          4.207820      Doug
# 187           0.492086          4.103579  no_owner
# 139           1.074713          4.077123      Dave
# 526           1.802998          4.062068      Doug
# 787           1.366027          3.959081  no_owner
# 215           1.802998          3.923645  no_owner
# 101           1.802998          3.870081      Will
# 626           0.929056          3.841899      Doug
# 51            0.929056          3.772236      Rory
# 507           1.948655          3.754415  no_owner
# 517           2.094312          3.682690  no_owner
# 311           1.220370          3.676071     Lucas
# 143           0.492086          3.668167  no_owner
# 146           1.802998          3.627947  no_owner
# 289           1.802998          3.541091  no_owner
# 783           1.948655          3.537355  no_owner
# 560           1.366027          3.519262  no_owner
# 445           1.802998          3.519107      Dave
# 505           1.802998          3.489837  no_owner
# 86            0.492086          3.480588  no_owner
# 671           1.074713          3.467912      Rory
# 588           1.948655          3.418239  no_owner
# 11            0.783400          3.410335  no_owner
# 383           2.239969          3.404148  no_owner
# 201           2.239969          3.395326  no_owner
# 522           1.657341          3.386983  no_owner
# 191           1.366027          3.354474  no_owner
# 528           1.511684          3.304109  no_owner
# 205           0.929056          3.296563  no_owner
# 265           1.220370          3.272827  no_owner

# %%
df_sorted.query('position=="FWD"').head(50)
# Out:
#                                full_name position            team  \
# 217                       erling_haaland      FWD        Man City
# 297     igor_thiago_nascimento_rodrigues      FWD       Brentford
# 343                         jarrod_bowen      FWD        West Ham
# 607                        ollie_watkins      FWD     Aston Villa
# 353                 jean_philippe_mateta      FWD  Crystal Palace
# 721                        thierno_barry      FWD         Everton
# 637               raul_jimenez_rodriguez      FWD          Fulham
# 523                          mateus_mane      FWD          Wolves
# 100                        brian_brobbey      FWD      Sunderland
# 242  francisco_evanilson_de_lima_barbosa      FWD     Bournemouth
# 83                        benjamin_sesko      FWD         Man Utd
# 757                 valentin_castellanos      FWD        West Ham
# 184                dominic_calvert_lewin      FWD           Leeds
# 61                         armando_broja      FWD         Burnley
# 288                         hugo_ekitike      FWD       Liverpool
# 760                      viktor_gyokeres      FWD         Arsenal
# 635                    randal_kolo_muani      FWD           Spurs
# 729                       tolu_arokodare      FWD          Wolves
# 461                           liam_delap      FWD         Chelsea
# 295            igor_jesus_maciel_da_cruz      FWD   Nott'm Forest
# 367        joao_pedro_junqueira_de_jesus      FWD         Chelsea
# 584                       nick_woltemade      FWD       Newcastle
# 786                          yoane_wissa      FWD       Newcastle
# 160                        danny_welbeck      FWD        Brighton
# 649               richarlison_de_andrade      FWD           Spurs
# 112                        callum_wilson      FWD        West Ham
# 408                        junior_kroupi      FWD     Bournemouth
# 198               eliezer_mayenda_dossou      FWD      Sunderland
# 401                       joshua_zirkzee      FWD         Man Utd
# 250            gabriel_fernando_de_jesus      FWD         Arsenal
# 478                         lukas_nmecha      FWD           Leeds
# 122                charalampos_kostoulas      FWD        Brighton
# 616        pablo_felipe_pereira_de_jesus      FWD        West Ham
# 392                 jorgen_strand_larsen      FWD          Wolves
# 28                        alexander_isak      FWD       Liverpool
# 595     norberto_bercique_gomes_betuncal      FWD         Everton
# 186             dominic_solanke_mitchell      FWD           Spurs
# 210                            enes_unal      FWD     Bournemouth
# 415                          kai_havertz      FWD         Arsenal
# 134                     christantus_uche      FWD  Crystal Palace
# 715                        taiwo_awoniyi      FWD   Nott'm Forest
# 133                           chris_wood      FWD   Nott'm Forest
# 776                        wilson_isidor      FWD      Sunderland
# 485                          lyle_foster      FWD         Burnley
# 589                      nicolas_jackson      FWD         Chelsea
# 164                 darwin_nunez_ribeiro      FWD       Liverpool
# 63                     arnaud_kalimuendo      FWD   Nott'm Forest
# 636                       rasmus_hojlund      FWD         Man Utd
# 387                     jonah_kusi_asare      FWD          Fulham
# 193                        eddie_nketiah      FWD  Crystal Palace
#
#      ewma_total_points  predicted_points     owner
# 217           1.074713          5.579102      Doug
# 297           4.133508          5.564142    Marcus
# 343           1.657341          4.820768     Lucas
# 607           1.657341          4.740574      Rory
# 353           1.511684          4.323258      Will
# 721           2.531282          4.200978  no_owner
# 637           1.366027          4.165289     Lucas
# 523           2.968253          4.151817  no_owner
# 100           2.385625          4.107428      Rory
# 242           1.802998          3.994770      Will
# 83            1.802998          3.718028    Marcus
# 757           0.200772          3.605496  no_owner
# 184           1.220370          3.579307      Dave
# 61            1.220370          3.393705  no_owner
# 288          -0.090542          3.355672      Dave
# 760           0.346429          3.344948      Doug
# 635           0.200772          3.326396      Rory
# 729           0.492086          3.107359  no_owner
# 461           1.220370          3.098502  no_owner
# 295           0.492086          3.087287  no_owner
# 367           1.074713          3.084468      Will
# 584           0.637743          2.828210    Marcus
# 786           0.783400          2.817269      Dave
# 160           0.200772          2.794815     Lucas
# 649           0.055115          2.741546  no_owner
# 112           1.220370          2.573426  no_owner
# 408           1.366027          2.551086  no_owner
# 198           0.200772          2.440229  no_owner
# 401           1.220370          2.353931  no_owner
# 250           0.346429          2.278763  no_owner
# 478           0.929056          2.075703  no_owner
# 122           1.220370          2.069596  no_owner
# 616          -0.090542          2.025407  no_owner
# 392           0.200772          1.921452  no_owner
# 28           -0.673169          1.775879      Doug
# 595           0.492086          1.676338  no_owner
# 186          -0.527513          1.457903  no_owner
# 210          -0.236199          1.310743  no_owner
# 415          -0.673169          1.283149  no_owner
# 134          -0.381856          1.280915  no_owner
# 715          -0.527513          1.244638  no_owner
# 133          -0.673169          1.198352  no_owner
# 776          -0.527513          1.150656  no_owner
# 485          -0.527513          1.149340  no_owner
# 589          -0.673169          1.101693  no_owner
# 164          -0.673169          1.083121  no_owner
# 63           -0.527513          1.079766  no_owner
# 636          -0.673169          1.028087  no_owner
# 387          -0.527513          0.960210  no_owner
# 193          -0.673169          0.940948  no_owner

# %%
a, b = get_best_11(df_sorted.query('owner=="Doug" and ~full_name.str.contains("reilly")'))
b
# Out:
#                            full_name position        team  ewma_total_points  \
# 9                     erling_haaland      FWD    Man City           1.074713
# 5                       james_garner      MID     Everton           3.696537
# 6                         phil_foden      MID    Man City           0.492086
# 1                     nathan_collins      DEF   Brentford           4.133508
# 7   matheus_santos_carneiro_da_cunha      MID     Man Utd           1.802998
# 2                      patrick_dorgu      DEF     Man Utd           2.676939
# 0                    jordan_pickford       GK     Everton           2.822596
# 8                   pedro_lomba_neto      MID     Chelsea           0.929056
# 3                pedro_porro_sauceda      DEF       Spurs           1.948655
# 4                      nordi_mukiele      DEF  Sunderland           2.822596
# 10                   viktor_gyokeres      FWD     Arsenal           0.346429
#
#     predicted_points owner
# 9           5.579102  Doug
# 5           4.742776  Doug
# 6           4.207820  Doug
# 1           4.078149  Doug
# 7           4.062068  Doug
# 2           3.985365  Doug
# 0           3.957191  Doug
# 8           3.841899  Doug
# 3           3.829363  Doug
# 4           3.633388  Doug
# 10          3.344948  Doug

# %%
rory_df = df_sorted.query('owner in ["no_owner", "Rory"]')
rory_df.query('position=="DEF"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                       full_name position           team  ewma_total_points  \
# 145             cristian_romero      DEF          Spurs           2.531282
# 762           vitalii_mykolenko      DEF        Everton           1.657341
# 551            micky_van_de_ven      DEF          Spurs           1.220370
# 742             trevoh_chalobah      DEF        Chelsea           1.657341
# 155              daniel_ballard      DEF     Sunderland           0.200772
# 287            hugo_bueno_lopez      DEF         Wolves           2.822596
# 785  yerson_mosquera_valdelamar      DEF         Wolves           2.385625
# 579               neco_williams      DEF  Nott'm Forest           1.074713
# 324                jake_o'brien      DEF        Everton           2.094312
# 620              pascal_struijk      DEF          Leeds           2.822596
# 341          jan_paul_van_hecke      DEF       Brighton           1.511684
# 483                   luke_shaw      DEF        Man Utd           0.783400
# 440             ladislav_krejci      DEF         Wolves           2.531282
# 548              michael_kayode      DEF      Brentford           1.220370
# 181        diogo_dalot_teixeira      DEF        Man Utd           0.783400
# 463           lisandro_martinez      DEF        Man Utd           1.511684
# 558                milos_kerkez      DEF      Liverpool           1.074713
# 436             kristoffer_ajer      DEF      Brentford           2.094312
# 55             antonee_robinson      DEF         Fulham           0.346429
# 567    murillo_costa_dos_santos      DEF  Nott'm Forest           1.366027
#
#      predicted_points     owner
# 145          3.373464      Rory
# 762          3.124516      Rory
# 551          3.021824      Rory
# 742          3.001992      Rory
# 155          1.921814      Rory
# 287          3.609643  no_owner
# 785          3.334146  no_owner
# 579          3.292605  no_owner
# 324          3.212997  no_owner
# 620          3.165276  no_owner
# 341          3.116009  no_owner
# 483          3.089647  no_owner
# 440          3.079323  no_owner
# 548          3.075094  no_owner
# 181          3.051195  no_owner
# 463          3.023400  no_owner
# 558          3.018674  no_owner
# 436          2.983609  no_owner
# 55           2.962511  no_owner
# 567          2.949658  no_owner

# %% [markdown]
# # Random stuff

# %%
sns.kdeplot(data=df_sorted, x='predicted_points', hue='position')
# Out:
# <Axes: xlabel='predicted_points', ylabel='Density'>

# %%
check_pred_vs_avg = df_sorted.melt(id_vars=['full_name', 'position'], value_vars=['predicted_points', 'ewma_total_points'])
sns.kdeplot(data=check_pred_vs_avg.query('position=="DEF"'), x='value', hue='variable')
# Out:
# <Axes: xlabel='value', ylabel='Density'>

# %%
a, b, = get_best_11(df_sorted)
b
# Out:
#                            full_name position       team  ewma_total_points  \
# 4    bruno_guimaraes_rodriguez_moura      MID  Newcastle           4.279165
# 5                      florian_wirtz      MID  Liverpool           3.113910
# 8                     erling_haaland      FWD   Man City           1.074713
# 9   igor_thiago_nascimento_rodrigues      FWD  Brentford           4.133508
# 6                     enzo_fernandez      MID    Chelsea           3.259567
# 10                      jarrod_bowen      FWD   West Ham           1.657341
# 7                       kevin_schade      MID  Brentford           1.657341
# 1                     nathan_collins      DEF  Brentford           4.133508
# 2       gabriel_dos_santos_magalhaes      DEF    Arsenal           4.861793
# 3                      patrick_dorgu      DEF    Man Utd           2.676939
# 0                    jordan_pickford       GK    Everton           2.822596
#
#     predicted_points   owner
# 4           6.121506  Marcus
# 5           5.869388   Lucas
# 8           5.579102    Doug
# 9           5.564142  Marcus
# 6           5.096164   Lucas
# 10          4.820768   Lucas
# 7           4.771998   Lucas
# 1           4.078149    Doug
# 2           4.033749    Will
# 3           3.985365    Doug
# 0           3.957191    Doug

# %%
owner_dict = get_owner_dict()
b['owner'] = b['owner'].map(owner_dict)

# %%
a, b = get_best_11(df_sorted.query('owner=="Doug"'))
b['predicted_points'].sum()
# Out:
# np.float64(45.2620695120493)

# %%
lucas_picked = df_sorted.query('owner=="Lucas" and full_name not in ["gianluigi_donnarumma", "mohammed_kudus", "riccardo_calafiori", "raul_jimenez_rodriguez"]')
lucas_picked['predicted_points'].sum()
# Out:
# np.float64(46.85915940857518)

# %%
nico = "nico_o'reilly"
doug_picked = df_sorted.query('owner=="Doug" and full_name not in ["bart_verbruggen", @nico, "pedro_lomba_neto", "alexander_isak"]')
doug_picked['predicted_points'].sum()
# Out:
# np.float64(44.66969284999513)

# %%
lw_results = pd.DataFrame({'User': ['Doug', 'Lucas', 'Will', 'Marcus', 'Dave', 'Rory'],
              'Predicted points': pred_points,
              'Actual points': [33, 13, 39, 36, 30, 42]}, 
              )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 lw_results = pd.DataFrame({'User': ['Doug', 'Lucas', 'Will', 'Marcus', 'Dave', 'Rory'],
# ----> 2               'Predicted points': pred_points,
#       3               'Actual points': [33, 13, 39, 36, 30, 42]},
#       4               )
#
# NameError: name 'pred_points' is not defined

# %%
lw_results.sort_values('Actual points', ascending=False)
# Out:
#      User  Predicted points  Actual points
# 5    Rory             33.34             42
# 2    Will             40.75             39
# 3  Marcus             32.91             36
# 0    Doug             39.28             33
# 4    Dave             36.83             30
# 1   Lucas             36.82             13

# %%
plt.figure(figsize=(3,3))
ax = sns.scatterplot(data=lw_results, x='Predicted points', y='Actual points', hue='User', s=100)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# # Figuring out how the model did last week

# %%
gw6 = pd.read_csv('predicted_gw6_simple.csv')
gw6
# Out:
#                 full_name position         team  ewma_total_points  \
# 0         aaron_anselmino      DEF      Chelsea             0.0000
# 1            aaron_hickey      DEF    Brentford             0.3129
# 2          aaron_ramsdale       GK    Newcastle             0.0000
# 3            aaron_ramsey      MID      Burnley             0.0000
# 4       aaron_wan_bissaka      DEF     West Ham             0.2401
# ..                    ...      ...          ...                ...
# 736  zain_silcott_duberry      MID  Bournemouth             0.0000
# 737           zak_johnson      DEF   Sunderland             0.0000
# 738          zeki_amdouni      FWD      Burnley             0.0000
# 739     zepiqueno_redmond      FWD  Aston Villa             0.0000
# 740         zian_flemming      FWD      Burnley             0.6430
#
#      predicted_points  owner
# 0            0.108120    NaN
# 1            0.214515    NaN
# 2            0.061611    NaN
# 3            0.178312    NaN
# 4            0.729524    NaN
# ..                ...    ...
# 736          0.263160    NaN
# 737          0.122112    NaN
# 738          0.067864    NaN
# 739          0.236978    NaN
# 740          0.862229    NaN
#
# [741 rows x 6 columns]

# %%
gw7 = pd.read_csv('predicted_gw7.csv')
gw6_7_merged = gw6.merge(gw7[['full_name', 'total_points']], on='full_name')

# %%
import numpy as np
import scipy
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error

# %%
x = gw6_7_merged['predicted_points']
y = gw6_7_merged['total_points']
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print(r_value)
# Out:
# 0.5529193700354283

# %%
sns.scatterplot(data=gw6_7_merged, x='predicted_points', y='total_points', hue='position')
x_range = np.linspace(0,6, 100)
y_range = slope*x_range + intercept
# plt.plot(x_range, y_range, color='black')

# %%
sns.scatterplot(data=gw6_7_merged, x='ewma_total_points', y='total_points', hue='position')
# Out:
# <Axes: xlabel='ewma_total_points', ylabel='total_points'>

# %%
df_full = pd.read_csv('predicted_gw20.csv')

# %% [markdown]
# # Checking individuals def

# %%
players = ['antonee_robinson', 'keane_lewis_potter', 'nordi_mukiele']

# %%
player = df_full.query('full_name in @players')

# %%
player_simple = player[['full_name', 'position', 'team', 'predicted_points', 'bps', 'creativity', 'ict_index', 'minutes', 'ewma_total_points', 'ewma_team_goals', 'ewma_team_points']]

# %%
multiplier_df = pd.DataFrame({'feature': ['bps', 'creativity', 'ict_index', 'minutes', 'ewma_total_points', 'ewma_team_goals', 'ewma_team_points'], 'multiplier': [0.151641, 0.118134, 0.092908, 0.503033, 0.156849, 0.010896, 0.058029]})
multiplier_df = multiplier_df.set_index('feature')

# %%
player_simple_multiplier = player_simple.set_index('full_name').T.merge(multiplier_df, left_index=True, right_index=True)

# %%
for player_name in players:
    player_simple_multiplier[f'{player_name}_multiplied'] = player_simple_multiplier[player_name] * player_simple_multiplier['multiplier']
# player_simple_multiplier['david_brooks_multiplied'] = player_simple_multiplier['david_brooks'] * player_simple_multiplier['multiplier']
# player_simple_multiplier['morgan_rogers_multiplied'] = player_simple_multiplier['morgan_rogers'] * player_simple_multiplier['multiplier']
# player_simple_multiplier['pedro _lomba_neto_multiplied'] = player_simple_multiplier['pedro_lomba_neto'] * player_simple_multiplier['multiplier']

# %%
player_simple_multiplier
# Out:
#                   antonee_robinson keane_lewis_potter nordi_mukiele  \
# bps                       2.651108           2.897228      2.897228
# creativity                4.436192           1.110737      0.466296
# ict_index                 2.786776           2.421911      1.276993
# minutes                   1.934215            1.69509      1.934215
# ewma_total_points         2.592152           4.296181      3.444167
# ewma_team_goals           0.394596           0.826878     -1.334533
# ewma_team_points          1.452349           0.848977      0.245604
#
#                    multiplier antonee_robinson_multiplied  \
# bps                  0.151641                    0.402017
# creativity           0.118134                    0.524065
# ict_index            0.092908                    0.258914
# minutes              0.503033                    0.972974
# ewma_total_points    0.156849                    0.406576
# ewma_team_goals      0.010896                      0.0043
# ewma_team_points     0.058029                    0.084278
#
#                   keane_lewis_potter_multiplied nordi_mukiele_multiplied
# bps                                    0.439339                 0.439339
# creativity                             0.131216                 0.055085
# ict_index                              0.225015                 0.118643
# minutes                                0.852686                 0.972974
# ewma_total_points                      0.673852                 0.540214
# ewma_team_goals                         0.00901                -0.014541
# ewma_team_points                       0.049265                 0.014252

# %%
player_simple_multiplier[['antonee_robinson_multiplied', 'keane_lewis_potter_multiplied', 'nordi_mukiele_multiplied']].sum()
# Out:
# antonee_robinson_multiplied      2.653124
# keane_lewis_potter_multiplied    2.380382
# nordi_mukiele_multiplied         2.125966
# dtype: object

# %%
plot = player_simple_multiplier.reset_index()[['index']+[f'{player_name}_multiplied' for player_name in players]].melt(var_name='player', value_name='contribution', id_vars='index')
sns.barplot(data=plot, x='index', y='contribution', hue='player')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# # Checking individuals mid

# %%
players = ['david_brooks', 'morgan_rogers', 'pedro_lomba_neto', 'justin_kluivert', 'james_garner']

# %%
player = df_full.query('full_name in @players')

# %%
player_simple = player[['full_name', 'position', 'team', 'predicted_points', 'clean_sheets', 'creativity', 'threat', 'ict_index', 'minutes', 'ewma_total_points']]

# %%
multiplier_df = pd.DataFrame({'feature': ['clean_sheets', 'creativity', 'threat', 'ict_index', 'minutes', 'ewma_total_points'], 'multiplier': [0.046647, 0.178292, 0.274799, 0.106039, 0.474493, 0.231377]})
multiplier_df = multiplier_df.set_index('feature')

# %%
player_simple_multiplier = player_simple.set_index('full_name').T.merge(multiplier_df, left_index=True, right_index=True)

# %%
for player_name in players:
    player_simple_multiplier[f'{player_name}_multiplied'] = player_simple_multiplier[player_name] * player_simple_multiplier['multiplier']
# player_simple_multiplier['david_brooks_multiplied'] = player_simple_multiplier['david_brooks'] * player_simple_multiplier['multiplier']
# player_simple_multiplier['morgan_rogers_multiplied'] = player_simple_multiplier['morgan_rogers'] * player_simple_multiplier['multiplier']
# player_simple_multiplier['pedro _lomba_neto_multiplied'] = player_simple_multiplier['pedro_lomba_neto'] * player_simple_multiplier['multiplier']

# %%
player_simple_multiplier
# Out:
#                   david_brooks james_garner justin_kluivert morgan_rogers  \
# clean_sheets          0.940541     2.373397        0.940541     -0.492314
# creativity            3.428586     3.595927        3.681377       1.37421
# threat                6.256681     0.386617         1.84545       3.37375
# ict_index             4.145581     2.900009        2.421911      3.352944
# minutes               0.708701     1.881906        1.396184      1.866961
# ewma_total_points      1.31413     3.444167         1.31413      3.870174
#
#                   pedro_lomba_neto  multiplier david_brooks_multiplied  \
# clean_sheets              0.940541    0.046647                0.043873
# creativity                4.318697    0.178292                0.611289
# threat                    1.289704    0.274799                 1.71933
# ict_index                  2.40933    0.106039                0.439593
# minutes                   1.597946    0.474493                0.336274
# ewma_total_points         0.888122    0.231377                0.304059
#
#                   morgan_rogers_multiplied pedro_lomba_neto_multiplied  \
# clean_sheets                     -0.022965                    0.043873
# creativity                        0.245011                    0.769989
# threat                            0.927103                    0.354409
# ict_index                         0.355543                    0.255483
# minutes                            0.88586                    0.758214
# ewma_total_points                 0.895469                    0.205491
#
#                   justin_kluivert_multiplied james_garner_multiplied
# clean_sheets                        0.043873                0.110712
# creativity                           0.65636                0.641125
# threat                              0.507128                0.106242
# ict_index                           0.256817                0.307514
# minutes                              0.66248                0.892951
# ewma_total_points                   0.304059                0.796901

# %%
player_simple_multiplier.sum()
# Out:
# david_brooks                   16.794219
# james_garner                   14.582023
# justin_kluivert                11.599594
# morgan_rogers                  13.345725
# pedro_lomba_neto                11.44434
# multiplier                      1.311647
# david_brooks_multiplied         3.454419
# morgan_rogers_multiplied        3.286021
# pedro_lomba_neto_multiplied      2.38746
# justin_kluivert_multiplied      2.430717
# james_garner_multiplied         2.855445
# dtype: object

# %%
plot = player_simple_multiplier.reset_index()[['index']+[f'{player_name}_multiplied' for player_name in players]].melt(var_name='player', value_name='contribution', id_vars='index')
sns.barplot(data=plot, x='index', y='contribution', hue='player')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
player_simple.set_index('full_name').T
# Out:
# full_name         david_brooks morgan_rogers pedro_lomba_neto
# position                   MID           MID              MID
# team               Bournemouth   Aston Villa          Chelsea
# predicted_points      5.010373      4.841976         3.943414
# clean_sheets          0.940541     -0.492314         0.940541
# creativity            3.428586       1.37421         4.318697
# threat                6.256681       3.37375         1.289704
# ict_index             4.145581      3.352944          2.40933
# minutes               0.708701      1.866961         1.597946
# ewma_total_points      1.31413      3.870174         0.888122

# %%
df_full.columns
# Out:
# Index(['full_name', 'gw', 'total_points', 'position', 'team', 'opponent_team',
#        'xP', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity',
#        'expected_assists', 'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'minutes', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'saves', 'starts', 'threat',
#        'ewma_total_points', 'transfers_balance', 'transfers_in',
#        'transfers_out', 'value', 'yellow_cards', 'opponent_team_name',
#        'ewma_team_goals', 'ewma_team_points', 'team_name_nw_opponent',
#        'team_nw_opponent', 'ewma_team_goals_nw_opponent',
#        'ewma_team_points_nw_opponent', 'predicted_points', 'owner'],
#       dtype='object')
