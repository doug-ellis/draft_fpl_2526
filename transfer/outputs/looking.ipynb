# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('predicted_gw6.csv_simple.csv')
df2 = pd.read_csv('predicted_gw6_26_training_simple.csv')

# %%
sns.kdeplot(data=df.melt(id_vars=['full_name', 'position']).query('variable=="predicted_points"'), x='value', hue='position')
# Out:
# <Axes: xlabel='value', ylabel='Density'>

# %%
df.sort_values('predicted_points', ascending=False).head(60)['position'].value_counts()
# Out:
# position
# DEF    28
# MID    24
# GK      7
# FWD     1
# Name: count, dtype: int64

# %%
df2.sort_values('predicted_points', ascending=False).head(60)['position'].value_counts()
# Out:
# position
# MID    37
# FWD    18
# DEF     4
# GK      1
# Name: count, dtype: int64

# %%
df.sort_values('predicted_points', ascending=False).query('position=="FWD"')
# Out:
#               full_name position       team  ewma_total_points  \
# 207      erling_haaland      FWD   Man City            10.0801
# 269        hugo_ekitike      FWD  Liverpool             6.6812
# 544      nick_woltemade      FWD  Newcastle             6.9000
# 323        jarrod_bowen      FWD   West Ham             5.1290
# 704     viktor_gyokeres      FWD    Arsenal             3.4819
# ..                  ...      ...        ...                ...
# 290         iwan_morgan      FWD  Brentford             0.0000
# 104     callum_marshall      FWD   West Ham             0.0000
# 535       nathan_fraser      FWD     Wolves             0.0000
# 220  fabio_soares_silva      FWD     Wolves             0.0000
# 420        leon_chiwome      FWD     Wolves             0.0000
#
#      predicted_points    owner
# 207          5.339121  88376.0
# 269          4.825278  85076.0
# 544          4.799495  93330.0
# 323          4.529150  85646.0
# 704          4.399343  88376.0
# ...
