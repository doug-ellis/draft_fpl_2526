# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from other_funcs import *

# %%
df = pd.read_csv('predicted_gw6_simple.csv')
df_sorted = df.sort_values('predicted_points', ascending=False)

# %%
sns.kdeplot(data=df.melt(id_vars=['full_name', 'position']).query('variable=="predicted_points"'), x='value', hue='position')
# Out:
# <Axes: xlabel='value', ylabel='Density'>

# %%
df_sorted.query('position=="DEF"').head(30)
# Out:
#                         full_name position            team  ewma_total_points  \
# 469           marcos_senesi_baron      DEF     Bournemouth             6.7943
# 466                    marc_guehi      DEF  Crystal Palace             7.2114
# 705               virgil_van_dijk      DEF       Liverpool             5.0850
# 343              joachim_andersen      DEF          Fulham             4.6328
# 698               tyrick_mitchell      DEF  Crystal Palace             6.8058
# 689               trevoh_chalobah      DEF         Chelsea             7.2048
# 140                      dan_burn      DEF       Newcastle             7.2087
# 149            daniel_munoz_mejia      DEF  Crystal Palace             4.6880
# 504               maxence_lacroix      DEF  Crystal Palace             5.7065
# 316               james_tarkowski      DEF         Everton             4.8046
# 237           gabriel_gudmundsson      DEF           Leeds             4.5810
# 267                 hjalmar_ekdal      DEF         Burnley             3.0472
# 568                 omar_alderete      DEF      Sunderland             4.7413
# 136               cristian_romero      DEF           Spurs             5.5749
# 604            riccardo_calafiori      DEF         Arsenal             6.4030
# 123                chris_richards      DEF  Crystal Palace             5.2824
# 499              matthijs_de_ligt      DEF         Man Utd             2.6377
# 674               tino_livramento      DEF       Newcastle             6.5145
# 700                  tyrone_mings      DEF     Aston Villa             4.8834
# 274               ibrahima_konate      DEF       Liverpool             4.2121
# 14                adrien_truffert      DEF     Bournemouth             4.7664
# 687                     trai_hume      DEF      Sunderland             4.2975
# 506                 maxime_esteve      DEF         Burnley             3.0445
# 577                pascal_struijk      DEF           Leeds             4.4228
# 540                 neco_williams      DEF   Nott'm Forest             3.5929
# 500                    matty_cash      DEF     Aston Villa             6.1766
# 198              emmanuel_agbadou      DEF          Wolves             2.2986
# 354                     joe_rodon      DEF           Leeds             4.3555
# 235  gabriel_dos_santos_magalhaes      DEF         Arsenal             4.8420
# 590           quilindschy_hartman      DEF         Burnley             2.4445
#
#      predicted_points    owner
# 469          3.981166  94654.0
# 466          3.876810  93330.0
# 705          3.815438  93330.0
# 343          3.815335  88376.0
# 698          3.741171  85646.0
# 689          3.675083  85076.0
# 140          3.665253      NaN
# 149          3.630469  87737.0
# 504          3.546331  94654.0
# 316          3.535446  88376.0
# 237          3.521678  88376.0
# 267          3.462715      NaN
# 568          3.461372      NaN
# 136          3.412516  85076.0
# 604          3.377468  85076.0
# 123          3.365719      NaN
# 499          3.365455      NaN
# 674          3.335124  88376.0
# 700          3.325884      NaN
# 274          3.306408  85646.0
# 14           3.258735  93330.0
# 687          3.254837      NaN
# 506          3.180938      NaN
# 577          3.155105      NaN
# 540          3.112191      NaN
# 500          3.100270      NaN
# 198          3.095727      NaN
# 354          3.083372      NaN
# 235          3.073538  87737.0
# 590          3.058772      NaN

# %%
df_sorted.head(60)['position'].value_counts()
# Out:
# position
# MID    27
# FWD    14
# DEF    14
# GK      5
# Name: count, dtype: int64

# %%
df_sorted['owner'].value_counts()
# Out:
# owner
# 88376.0    15
# 87737.0    15
# 93330.0    15
# 85076.0    15
# 85646.0    15
# 94654.0    15
# Name: count, dtype: int64

# %%
df_de = df_sorted.query('owner==88376.0')
df_de
# Out:
#                  full_name position           team  ewma_total_points  \
# 207         erling_haaland      FWD       Man City            10.0801
# 704        viktor_gyokeres      FWD        Arsenal             3.4819
# 670      tijjani_reijnders      MID       Man City             6.2308
# 280          iliman_ndiaye      MID        Everton             5.1824
# 343       joachim_andersen      DEF         Fulham             4.6328
# 526     morgan_gibbs_white      MID  Nott'm Forest             2.7203
# 316        james_tarkowski      DEF        Everton             4.8046
# 237    gabriel_gudmundsson      DEF          Leeds             4.5810
# 176     dominik_szoboszlai      MID      Liverpool             3.5270
# 674        tino_livramento      DEF      Newcastle             6.5145
# 367        jordan_pickford       GK        Everton             3.7307
# 178         dorde_petrovic       GK    Bournemouth             4.0526
# 465  marc_cucurella_saseta      DEF        Chelsea             3.5273
# 586             phil_foden      MID       Man City             3.5229
# 27          alexander_isak      FWD      Liverpool             0.3000
#
#      predicted_points    owner
# 207          5.339121  88376.0
# 704          4.399343  88376.0
# 670          4.372924  88376.0
# 280          4.087982  88376.0
# 343          3.815335  88376.0
# 526          3.693933  88376.0
# 316          3.535446  88376.0
# 237          3.521678  88376.0
# 176          3.513041  88376.0
# 674          3.335124  88376.0
# 367          3.271128  88376.0
# 178          3.092016  88376.0
# 465          2.626843  88376.0
# 586          2.180072  88376.0
# 27           0.806416  88376.0

# %%
get_all_best_11s(df_sorted)
# Out:
# Doug: predicted points 42.89
# Marcus: predicted points 40.37
# Will: predicted points 40.32
# Lucas: predicted points 41.01
# Dave: predicted points 36.89
# Rory: predicted points 38.39

# %%
lw_results = pd.DataFrame({'User': ['Doug', 'Lucas', 'Will', 'Marcus', 'Dave', 'Rory'],
              'Predicted points': [43.57, 42.95, 40.77, 40.96, 36.66, 38.82],
              'Actual points': [31, 35, 53, 31, 43, 38]}, 
              )

# %%
lw_results.sort_values('Actual points', ascending=False)
# Out:
#      User  Predicted points  Actual points
# 2    Will             40.77             53
# 4    Dave             36.66             43
# 5    Rory             38.82             38
# 1   Lucas             42.95             35
# 0    Doug             43.57             31
# 3  Marcus             40.96             31

# %%
plt.figure(figsize=(3,3))
ax = sns.scatterplot(data=lw_results, x='Predicted points', y='Actual points', hue='User', s=100)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# # Figuring out how the model did last week

# %%
gw5 = pd.read_csv('predicted_gw5_simple.csv')
gw5
# Out:
#                 full_name position         team  ewma_total_points  \
# 0         aaron_anselmino      DEF      Chelsea              0.000
# 1            aaron_hickey      DEF    Brentford              0.447
# 2          aaron_ramsdale       GK    Newcastle              0.000
# 3            aaron_ramsey      MID      Burnley              0.000
# 4       aaron_wan_bissaka      DEF     West Ham              0.343
# ..                    ...      ...          ...                ...
# 735  zain_silcott_duberry      MID  Bournemouth              0.000
# 736           zak_johnson      DEF   Sunderland              0.000
# 737          zeki_amdouni      FWD      Burnley              0.000
# 738     zepiqueno_redmond      FWD  Aston Villa              0.000
# 739         zian_flemming      FWD      Burnley              0.490
#
#      predicted_points  owner
# 0            0.142668    NaN
# 1            0.541277    NaN
# 2            0.329702    NaN
# 3            0.058283    NaN
# 4            1.661107    NaN
# ..                ...    ...
# 735          0.298579    NaN
# 736          0.278476    NaN
# 737          0.058283    NaN
# 738          0.269579    NaN
# 739          0.767169    NaN
#
# [740 rows x 6 columns]

# %%
gw6 = pd.read_csv('predicted_gw6.csv')
gw5_6_merged = gw5.merge(gw6[['full_name', 'total_points']], on='full_name')

# %%
import numpy as np
import scipy
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error

# %%
x = gw5_6_merged['predicted_points']
y = gw5_6_merged['total_points']
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print(r_value)
# Out:
# 0.5249100924102825

# %%
sns.scatterplot(data=gw5_6_merged, y='predicted_points', x='total_points', hue='position')
x_range = np.linspace(0,15, 100)
y_range = slope*x_range + intercept
# plt.plot(x_range, y_range, color='black')

# %%
# Out:
# 0.5249100924102825

# %%
root_mean_squared_error(x, y)
# Out:
# 2.236625027969016
