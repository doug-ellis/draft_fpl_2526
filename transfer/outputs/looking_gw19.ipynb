# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from other_funcs import *

# %%
df = pd.read_csv('predicted_gw18_simple.csv')
df_sorted = df.sort_values('predicted_points', ascending=False)

# %%
df_sorted.query('owner==88376.0')
# Out:
#                             full_name position            team  \
# 209                    erling_haaland      FWD        Man City
# 509  matheus_santos_carneiro_da_cunha      MID         Man Utd
# 607                        phil_foden      MID        Man City
# 604                  pedro_lomba_neto      MID         Chelsea
# 179                dominik_szoboszlai      MID       Liverpool
# 375                   jordan_pickford       GK         Everton
# 751                    yankuba_minteh      MID        Brighton
# 69                    bart_verbruggen       GK        Brighton
# 568                     nico_o'reilly      DEF        Man City
# 482             marc_cucurella_saseta      DEF         Chelsea
# 327                jan_paul_van_hecke      DEF        Brighton
# 731                   viktor_gyokeres      FWD         Arsenal
# 126                    chris_richards      DEF  Crystal Palace
# 219                  ezri_konsa_ngoyo      DEF     Aston Villa
# 28                     alexander_isak      FWD       Liverpool
#
#      ewma_total_points  predicted_points    owner
# 209              11.25          5.344560  88376.0
# 509               6.25          5.122285  88376.0
# 607              10.75          4.780739  88376.0
# 604               4.00          3.899096  88376.0
# 179               3.50          3.789567  88376.0
# 375               4.25          3.403999  88376.0
# 751               2.50          3.332058  88376.0
# 69                4.00          3.014671  88376.0
# 568               4.50          2.761354  88376.0
# 482               3.50          2.679898  88376.0
# 327               4.50          2.379120  88376.0
# 731               2.25          2.348759  88376.0
# 126               4.00          2.332071  88376.0
# 219               1.50          2.332070  88376.0
# 28                2.50          1.862765  88376.0

# %%
owner_dict = get_owner_dict()
df_sorted['owner'] = df_sorted['owner'].map(owner_dict)
df_sorted['owner'] = df_sorted['owner'].fillna('no_owner')

# %%
transfer_df = df_sorted.query('owner in ["no_owner", "Doug"]')

# %%
transfer_df.query('position=="GK"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                       full_name position           team  ewma_total_points  \
# 375             jordan_pickford       GK        Everton               4.25
# 69              bart_verbruggen       GK       Brighton               4.00
# 2                aaron_ramsdale       GK      Newcastle               1.50
# 181              dorde_petrovic       GK    Bournemouth               3.00
# 452         lucas_estella_perri       GK          Leeds               1.75
# 84                   bernd_leno       GK         Fulham               3.00
# 497             martin_dubravka       GK        Burnley               2.00
# 32              alphonse_areola       GK       West Ham               2.25
# 657               sam_johnstone       GK         Wolves               0.50
# 371  john_victor_maciel_furtado       GK  Nott'm Forest               1.75
# 520                   matz_sels       GK  Nott'm Forest               2.00
# 485                 marco_bizot       GK    Aston Villa               0.50
# 379         jose_malheiro_de_sa       GK         Wolves               0.50
# 645         ronnie_hollingshead       GK    Aston Villa               0.00
# 230             filip_marschall       GK    Aston Villa               0.00
# 685        stefan_ortega_moreno       GK       Man City               0.00
# 487           marcus_bettinelli       GK       Man City               0.00
# 186   ederson_santana_de_moraes       GK       Man City               0.00
# 323              james_trafford       GK       Man City               0.00
# 325                james_wright       GK    Aston Villa               0.00
#
#      predicted_points     owner
# 375          3.403999      Doug
# 69           3.014671      Doug
# 2            3.089410  no_owner
# 181          3.089008  no_owner
# 452          2.978197  no_owner
# 84           2.931504  no_owner
# 497          2.930834  no_owner
# 32           2.780658  no_owner
# 657          2.111003  no_owner
# 371          1.843301  no_owner
# 520          1.739445  no_owner
# 485          1.635156  no_owner
# 379          0.813910  no_owner
# 645          0.278378  no_owner
# 230          0.278378  no_owner
# 685          0.278378  no_owner
# 487          0.278378  no_owner
# 186          0.278378  no_owner
# 323          0.278378  no_owner
# 325          0.278378  no_owner

# %%
transfer_df.query('position=="DEF"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                  full_name position            team  ewma_total_points  \
# 568          nico_o'reilly      DEF        Man City               4.50
# 482  marc_cucurella_saseta      DEF         Chelsea               3.50
# 327     jan_paul_van_hecke      DEF        Brighton               4.50
# 126         chris_richards      DEF  Crystal Palace               4.00
# 219       ezri_konsa_ngoyo      DEF     Aston Villa               1.50
# 560          neco_williams      DEF   Nott'm Forest               4.50
# 173   diogo_dalot_teixeira      DEF         Man Utd               5.50
# 589          omar_alderete      DEF      Sunderland               4.50
# 310           jake_o'brien      DEF         Everton               4.25
# 476             malo_gusto      DEF         Chelsea               6.25
# 598         pascal_struijk      DEF           Leeds               2.50
# 149         daniel_ballard      DEF      Sunderland               5.50
# 241    gabriel_gudmundsson      DEF           Leeds               2.00
# 605    pedro_porro_sauceda      DEF           Spurs               1.75
# 139        cristian_romero      DEF           Spurs               6.00
# 23    alex_jimenez_sanchez      DEF     Bournemouth               3.75
# 276            ian_maatsen      DEF     Aston Villa               1.50
# 733      vitalii_mykolenko      DEF         Everton               3.00
# 309             jaka_bijol      DEF           Leeds               5.00
# 334           jayden_bogle      DEF           Leeds               3.25
#
#      predicted_points     owner
# 568          2.761354      Doug
# 482          2.679898      Doug
# 327          2.379120      Doug
# 126          2.332071      Doug
# 219          2.332070      Doug
# 560          3.096635  no_owner
# 173          3.061806  no_owner
# 589          2.917365  no_owner
# 310          2.790009  no_owner
# 476          2.738032  no_owner
# 598          2.719165  no_owner
# 149          2.685232  no_owner
# 241          2.682300  no_owner
# 605          2.662768  no_owner
# 139          2.629890  no_owner
# 23           2.611654  no_owner
# 276          2.604183  no_owner
# 733          2.575284  no_owner
# 309          2.528916  no_owner
# 334          2.520520  no_owner

# %%
transfer_df.query('position=="MID"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                             full_name position            team  \
# 509  matheus_santos_carneiro_da_cunha      MID         Man Utd
# 607                        phil_foden      MID        Man City
# 604                  pedro_lomba_neto      MID         Chelsea
# 179                dominik_szoboszlai      MID       Liverpool
# 751                    yankuba_minteh      MID        Brighton
# 52                        anton_stach      MID           Leeds
# 34                        amad_diallo      MID         Man Utd
# 297                     jack_grealish      MID         Everton
# 247                  georginio_rutter      MID        Brighton
# 592                  omari_hutchinson      MID   Nott'm Forest
# 197                  emile_smith_rowe      MID          Fulham
# 755                yeremy_pino_santos      MID  Crystal Palace
# 113              carlos_alcaraz_duran      MID         Everton
# 20        alejandro_garnacho_ferreyra      MID         Chelsea
# 314                      james_garner      MID         Everton
# 207                       enzo_le_fee      MID      Sunderland
# 546                morgan_gibbs_white      MID   Nott'm Forest
# 573                       noah_okafor      MID           Leeds
# 193                   elliot_anderson      MID   Nott'm Forest
# 11                       adam_wharton      MID  Crystal Palace
#
#      ewma_total_points  predicted_points     owner
# 509               6.25          5.122285      Doug
# 607              10.75          4.780739      Doug
# 604               4.00          3.899096      Doug
# 179               3.50          3.789567      Doug
# 751               2.50          3.332058      Doug
# 52                7.00          4.445325  no_owner
# 34                3.75          3.735214  no_owner
# 297               4.50          3.730548  no_owner
# 247               3.25          3.593614  no_owner
# 592               3.75          3.573072  no_owner
# 197               5.00          3.529648  no_owner
# 755               3.00          3.395637  no_owner
# 113               3.00          3.272993  no_owner
# 20                2.00          3.150302  no_owner
# 314               3.50          3.091267  no_owner
# 207               2.75          3.079489  no_owner
# 546               2.50          3.061323  no_owner
# 573               2.75          3.057141  no_owner
# 193               3.25          3.047100  no_owner
# 11                4.75          3.046734  no_owner

# %%
transfer_df.query('position=="FWD"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                             full_name position            team  \
# 209                    erling_haaland      FWD        Man City
# 731                   viktor_gyokeres      FWD         Arsenal
# 28                     alexander_isak      FWD       Liverpool
# 281         igor_jesus_maciel_da_cruz      FWD   Nott'm Forest
# 613                 randal_kolo_muani      FWD           Spurs
# 696                     thierno_barry      FWD         Everton
# 377              jorgen_strand_larsen      FWD          Wolves
# 185                     eddie_nketiah      FWD  Crystal Palace
# 96                      brian_brobbey      FWD      Sunderland
# 59                      armando_broja      FWD         Burnley
# 468                       lyle_foster      FWD         Burnley
# 769                     zian_flemming      FWD         Burnley
# 108                     callum_wilson      FWD        West Ham
# 393                     junior_kroupi      FWD     Bournemouth
# 747                     wilson_isidor      FWD      Sunderland
# 506                       mateus_mane      FWD          Wolves
# 118             charalampos_kostoulas      FWD        Brighton
# 703                    tolu_arokodare      FWD          Wolves
# 445                        liam_delap      FWD         Chelsea
# 576  norberto_bercique_gomes_betuncal      FWD         Everton
#
#      ewma_total_points  predicted_points     owner
# 209              11.25          5.344560      Doug
# 731               2.25          2.348759      Doug
# 28                2.50          1.862765      Doug
# 281               3.75          3.868405  no_owner
# 613               2.00          3.274441  no_owner
# 696               2.75          3.044617  no_owner
# 377               1.25          2.990288  no_owner
# 185               3.25          2.634021  no_owner
# 96                1.50          2.519043  no_owner
# 59                3.00          2.466092  no_owner
# 468               1.25          2.105718  no_owner
# 769               2.00          1.967988  no_owner
# 108               2.00          1.762473  no_owner
# 393               2.00          1.725313  no_owner
# 747               0.75          1.488719  no_owner
# 506               1.75          1.401590  no_owner
# 118               1.00          1.354752  no_owner
# 703               2.50          1.319172  no_owner
# 445               0.75          1.252946  no_owner
# 576               1.00          1.152997  no_owner

# %%
df_sorted.query('position=="GK"').head(50)
# Out:
#                             full_name position            team  \
# 634                       robin_roefs       GK      Sunderland
# 248              gianluigi_donnarumma       GK        Man City
# 375                   jordan_pickford       GK         Everton
# 162                 david_raya_martin       GK         Arsenal
# 633              robert_lynch_sanchez       GK         Chelsea
# 31                     alisson_becker       GK       Liverpool
# 2                      aaron_ramsdale       GK       Newcastle
# 181                    dorde_petrovic       GK     Bournemouth
# 253                 guglielmo_vicario       GK           Spurs
# 69                    bart_verbruggen       GK        Brighton
# 111                 caoimhin_kelleher       GK       Brentford
# 452               lucas_estella_perri       GK           Leeds
# 163                    dean_henderson       GK  Crystal Palace
# 84                         bernd_leno       GK          Fulham
# 497                   martin_dubravka       GK         Burnley
# 673                     senne_lammens       GK         Man Utd
# 32                    alphonse_areola       GK        West Ham
# 657                     sam_johnstone       GK          Wolves
# 371        john_victor_maciel_furtado       GK   Nott'm Forest
# 520                         matz_sels       GK   Nott'm Forest
# 199          emiliano_martinez_romero       GK     Aston Villa
# 485                       marco_bizot       GK     Aston Villa
# 379               jose_malheiro_de_sa       GK          Wolves
# 645               ronnie_hollingshead       GK     Aston Villa
# 230                   filip_marschall       GK     Aston Villa
# 685              stefan_ortega_moreno       GK        Man City
# 487                 marcus_bettinelli       GK        Man City
# 186         ederson_santana_de_moraes       GK        Man City
# 323                    james_trafford       GK        Man City
# 325                      james_wright       GK     Aston Villa
# 355                         joe_gauci       GK     Aston Villa
# 658                       sam_proctor       GK     Aston Villa
# 403                         karl_hein       GK         Arsenal
# 711                     tommy_setford       GK         Arsenal
# 407        kepa_arrizabalaga_revuelta       GK         Arsenal
# 238                   freddie_woodman       GK       Liverpool
# 249              giorgi_mamardashvili       GK       Liverpool
# 287                     illan_meslier       GK           Leeds
# 21                        alex_cairns       GK           Leeds
# 402                       karl_darlow       GK           Leeds
# 60                        armin_pecsi       GK       Liverpool
# 516                       matt_turner       GK   Nott'm Forest
# 623                     remi_matthews       GK  Crystal Palace
# 492                      mark_travers       GK         Everton
# 47                         angus_gunn       GK   Nott'm Forest
# 268                       harry_tyrer       GK         Everton
# 736                    walter_benitez       GK  Crystal Palace
# 116  carlos_miguel_dos_santos_pereira       GK   Nott'm Forest
# 707                          tom_king       GK         Everton
# 688                      steven_benda       GK          Fulham
#
#      ewma_total_points  predicted_points     owner
# 634               5.00          3.492412      Rory
# 248               5.00          3.431785     Lucas
# 375               4.25          3.403999      Doug
# 162               4.25          3.403354      Dave
# 633               5.25          3.282252    Marcus
# 31                3.50          3.196259      Will
# 2                 1.50          3.089410  no_owner
# 181               3.00          3.089008  no_owner
# 253               2.75          3.019263    Marcus
# 69                4.00          3.014671      Doug
# 111               5.00          2.982065      Dave
# 452               1.75          2.978197  no_owner
# 163               2.75          2.972515      Will
# 84                3.00          2.931504  no_owner
# 497               2.00          2.930834  no_owner
# 673               1.50          2.875865      Rory
# 32                2.25          2.780658  no_owner
# 657               0.50          2.111003  no_owner
# 371               1.75          1.843301  no_owner
# 520               2.00          1.739445  no_owner
# 199               1.75          1.694231     Lucas
# 485               0.50          1.635156  no_owner
# 379               0.50          0.813910  no_owner
# 645               0.00          0.278378  no_owner
# 230               0.00          0.278378  no_owner
# 685               0.00          0.278378  no_owner
# 487               0.00          0.278378  no_owner
# 186               0.00          0.278378  no_owner
# 323               0.00          0.278378  no_owner
# 325               0.00          0.278378  no_owner
# 355               0.00          0.278378  no_owner
# 658               0.00          0.278378  no_owner
# 403               0.00          0.253186  no_owner
# 711               0.00          0.253186  no_owner
# 407               0.00          0.253186  no_owner
# 238               0.00          0.244789  no_owner
# 249               0.00          0.244789  no_owner
# 287               0.00          0.244789  no_owner
# 21                0.00          0.244789  no_owner
# 402               0.00          0.244789  no_owner
# 60                0.00          0.244789  no_owner
# 516               0.00          0.227994  no_owner
# 623               0.00          0.227994  no_owner
# 492               0.00          0.227994  no_owner
# 47                0.00          0.227994  no_owner
# 268               0.00          0.227994  no_owner
# 736               0.00          0.227994  no_owner
# 116               0.00          0.227994  no_owner
# 707               0.00          0.227994  no_owner
# 688               0.00          0.227994  no_owner

# %%
df_sorted.query('position=="DEF"').head(50)
# Out:
#                             full_name position            team  \
# 508                     matheus_nunes      DEF        Man City
# 560                     neco_williams      DEF   Nott'm Forest
# 387                    josko_gvardiol      DEF        Man City
# 173              diogo_dalot_teixeira      DEF         Man Utd
# 647  ruben_dos_santos_gato_alves_dias      DEF        Man City
# 589                     omar_alderete      DEF      Sunderland
# 483                        marc_guehi      DEF  Crystal Palace
# 519                        matty_cash      DEF     Aston Villa
# 310                      jake_o'brien      DEF         Everton
# 568                     nico_o'reilly      DEF        Man City
# 609                    piero_hincapie      DEF         Arsenal
# 476                        malo_gusto      DEF         Chelsea
# 598                    pascal_struijk      DEF           Leeds
# 716                   trevoh_chalobah      DEF         Chelsea
# 322                   james_tarkowski      DEF         Everton
# 149                    daniel_ballard      DEF      Sunderland
# 241               gabriel_gudmundsson      DEF           Leeds
# 482             marc_cucurella_saseta      DEF         Chelsea
# 605               pedro_porro_sauceda      DEF           Spurs
# 732                   virgil_van_dijk      DEF       Liverpool
# 139                   cristian_romero      DEF           Spurs
# 14                    adrien_truffert      DEF     Bournemouth
# 23               alex_jimenez_sanchez      DEF     Bournemouth
# 276                       ian_maatsen      DEF     Aston Villa
# 733                 vitalii_mykolenko      DEF         Everton
# 279                   ibrahima_konate      DEF       Liverpool
# 309                        jaka_bijol      DEF           Leeds
# 334                      jayden_bogle      DEF           Leeds
# 578                     nordi_mukiele      DEF      Sunderland
# 524                   maxim_de_cuyper      DEF        Brighton
# 394                    jurrien_timber      DEF         Arsenal
# 529                    michael_kayode      DEF       Brentford
# 572                 nikola_milenkovic      DEF   Nott'm Forest
# 327                jan_paul_van_hecke      DEF        Brighton
# 618                       reece_james      DEF         Chelsea
# 228                    ferdi_kadioglu      DEF        Brighton
# 571                     nicolo_savona      DEF   Nott'm Forest
# 725                   tyrick_mitchell      DEF  Crystal Palace
# 406                        kenny_tete      DEF          Fulham
# 126                    chris_richards      DEF  Crystal Palace
# 219                  ezri_konsa_ngoyo      DEF     Aston Villa
# 81                     benjamin_white      DEF         Arsenal
# 349                  joachim_andersen      DEF          Fulham
# 674                 sepp_van_den_berg      DEF       Brentford
# 523                   maxence_lacroix      DEF  Crystal Palace
# 539                      milos_kerkez      DEF       Liverpool
# 441                        lewis_hall      DEF       Newcastle
# 404                keane_lewis_potter      DEF       Brentford
# 68                     bafode_diakite      DEF     Bournemouth
# 159                david_moller_wolfe      DEF          Wolves
#
#      ewma_total_points  predicted_points     owner
# 508               6.75          3.305812     Lucas
# 560               4.50          3.096635  no_owner
# 387               6.50          3.076806      Dave
# 173               5.50          3.061806  no_owner
# 647               7.00          3.035476    Marcus
# 589               4.50          2.917365  no_owner
# 483               6.00          2.836963    Marcus
# 519               3.75          2.803289      Dave
# 310               4.25          2.790009  no_owner
# 568               4.50          2.761354      Doug
# 609               6.25          2.745179      Rory
# 476               6.25          2.738032  no_owner
# 598               2.50          2.719165  no_owner
# 716               6.00          2.691220      Rory
# 322               5.75          2.690387    Marcus
# 149               5.50          2.685232  no_owner
# 241               2.00          2.682300  no_owner
# 482               3.50          2.679898      Doug
# 605               1.75          2.662768  no_owner
# 732               3.50          2.644299    Marcus
# 139               6.00          2.629890  no_owner
# 14                3.75          2.618546    Marcus
# 23                3.75          2.611654  no_owner
# 276               1.50          2.604183  no_owner
# 733               3.00          2.575284  no_owner
# 279               3.75          2.560038     Lucas
# 309               5.00          2.528916  no_owner
# 334               3.25          2.520520  no_owner
# 578               3.75          2.499467  no_owner
# 524               3.50          2.467575  no_owner
# 394               3.00          2.460589      Will
# 529               2.75          2.418329  no_owner
# 572               3.75          2.387748  no_owner
# 327               4.50          2.379120      Doug
# 618               4.75          2.373671      Will
# 228               2.25          2.367583  no_owner
# 571               3.00          2.363066  no_owner
# 725               2.25          2.343582      Dave
# 406               3.50          2.339782  no_owner
# 126               4.00          2.332071      Doug
# 219               1.50          2.332070      Doug
# 81                4.00          2.304002  no_owner
# 349               2.50          2.291996     Lucas
# 674               3.25          2.287501  no_owner
# 523               3.00          2.282040      Rory
# 539               2.75          2.268084  no_owner
# 441               2.50          2.253714  no_owner
# 404               7.25          2.251739  no_owner
# 68                3.00          2.248812      Will
# 159               1.75          2.246011  no_owner

# %%
df_sorted.query('position=="MID"').head(50)
# Out:
#                             full_name position            team  \
# 97             bruno_borges_fernandes      MID         Man Utd
# 509  matheus_santos_carneiro_da_cunha      MID         Man Utd
# 547                     morgan_rogers      MID     Aston Villa
# 607                        phil_foden      MID        Man City
# 51                    antoine_semenyo      MID     Bournemouth
# 52                        anton_stach      MID           Leeds
# 232                     florian_wirtz      MID       Liverpool
# 101                       bukayo_saka      MID         Arsenal
# 269                      harry_wilson      MID          Fulham
# 604                  pedro_lomba_neto      MID         Chelsea
# 617                      rayan_cherki      MID        Man City
# 164                       declan_rice      MID         Arsenal
# 179                dominik_szoboszlai      MID       Liverpool
# 34                        amad_diallo      MID         Man Utd
# 297                     jack_grealish      MID         Everton
# 100                      bryan_mbeumo      MID         Man Utd
# 247                  georginio_rutter      MID        Brighton
# 592                  omari_hutchinson      MID   Nott'm Forest
# 197                  emile_smith_rowe      MID          Fulham
# 49                     anthony_gordon      MID       Newcastle
# 755                yeremy_pino_santos      MID  Crystal Palace
# 498                   martin_odegaard      MID         Arsenal
# 751                    yankuba_minteh      MID        Brighton
# 98    bruno_guimaraes_rodriguez_moura      MID       Newcastle
# 113              carlos_alcaraz_duran      MID         Everton
# 490                  marcus_tavernier      MID     Bournemouth
# 649                  ryan_gravenberch      MID       Liverpool
# 697                 tijjani_reijnders      MID        Man City
# 20        alejandro_garnacho_ferreyra      MID         Chelsea
# 206                    enzo_fernandez      MID         Chelsea
# 544                    mohammed_kudus      MID           Spurs
# 314                      james_garner      MID         Everton
# 207                       enzo_le_fee      MID      Sunderland
# 546                morgan_gibbs_white      MID   Nott'm Forest
# 573                       noah_okafor      MID           Leeds
# 193                   elliot_anderson      MID   Nott'm Forest
# 11                       adam_wharton      MID  Crystal Palace
# 105                callum_hudson_odoi      MID   Nott'm Forest
# 285                     iliman_ndiaye      MID         Everton
# 302                jacob_bruun_larsen      MID         Burnley
# 505  mateus_goncalo_espanha_fernandes      MID        West Ham
# 512                      mats_wieffer      MID        Brighton
# 368                       john_mcginn      MID     Aston Villa
# 758                   youri_tielemans      MID     Aston Villa
# 436                  lesley_ugochukwu      MID         Burnley
# 211                      ethan_ampadu      MID           Leeds
# 35                       amadou_onana      MID     Aston Villa
# 381                       josh_cullen      MID         Burnley
# 396                   justin_kluivert      MID     Bournemouth
# 501                       mason_mount      MID         Man Utd
#
#      ewma_total_points  predicted_points     owner
# 97                9.00          5.157882      Will
# 509               6.25          5.122285      Doug
# 547               9.50          4.801185    Marcus
# 607              10.75          4.780739      Doug
# 51                5.75          4.743683      Will
# 52                7.00          4.445325  no_owner
# 232               5.75          4.300755     Lucas
# 101               6.00          4.294974      Will
# 269               8.50          4.122352      Dave
# 604               4.00          3.899096      Doug
# 617               5.50          3.876093      Dave
# 164               5.50          3.838305      Rory
# 179               3.50          3.789567      Doug
# 34                3.75          3.735214  no_owner
# 297               4.50          3.730548  no_owner
# 100               3.00          3.640394    Marcus
# 247               3.25          3.593614  no_owner
# 592               3.75          3.573072  no_owner
# 197               5.00          3.529648  no_owner
# 49                6.75          3.486370      Rory
# 755               3.00          3.395637  no_owner
# 498               2.25          3.391367    Marcus
# 751               2.50          3.332058      Doug
# 98                5.00          3.278582    Marcus
# 113               3.00          3.272993  no_owner
# 490               5.00          3.240839      Dave
# 649               4.25          3.206143      Rory
# 697               4.75          3.188392      Will
# 20                2.00          3.150302  no_owner
# 206               2.25          3.116472     Lucas
# 544               3.25          3.113525     Lucas
# 314               3.50          3.091267  no_owner
# 207               2.75          3.079489  no_owner
# 546               2.50          3.061323  no_owner
# 573               2.75          3.057141  no_owner
# 193               3.25          3.047100  no_owner
# 11                4.75          3.046734  no_owner
# 105               5.75          3.021626  no_owner
# 285               3.25          2.942491      Will
# 302               2.00          2.933522  no_owner
# 505               5.00          2.932832  no_owner
# 512               3.25          2.870971  no_owner
# 368               2.50          2.839524  no_owner
# 758               2.75          2.828809  no_owner
# 436               3.50          2.813907  no_owner
# 211               5.00          2.806414  no_owner
# 35                4.75          2.788344  no_owner
# 381               3.00          2.758384  no_owner
# 396               2.50          2.735202  no_owner
# 501               3.00          2.722711  no_owner

# %%
df_sorted.query('position=="FWD"').head(50)
# Out:
#                                full_name position            team  \
# 209                       erling_haaland      FWD        Man City
# 176                dominic_calvert_lewin      FWD           Leeds
# 274                         hugo_ekitike      FWD       Liverpool
# 329                         jarrod_bowen      FWD        West Ham
# 587                        ollie_watkins      FWD     Aston Villa
# 281            igor_jesus_maciel_da_cruz      FWD   Nott'm Forest
# 565                       nick_woltemade      FWD       Newcastle
# 615               raul_jimenez_rodriguez      FWD          Fulham
# 352        joao_pedro_junqueira_de_jesus      FWD         Chelsea
# 613                    randal_kolo_muani      FWD           Spurs
# 696                        thierno_barry      FWD         Everton
# 627               richarlison_de_andrade      FWD           Spurs
# 377                 jorgen_strand_larsen      FWD          Wolves
# 283     igor_thiago_nascimento_rodrigues      FWD       Brentford
# 233  francisco_evanilson_de_lima_barbosa      FWD     Bournemouth
# 339                 jean_philippe_mateta      FWD  Crystal Palace
# 185                        eddie_nketiah      FWD  Crystal Palace
# 96                         brian_brobbey      FWD      Sunderland
# 59                         armando_broja      FWD         Burnley
# 731                      viktor_gyokeres      FWD         Arsenal
# 468                          lyle_foster      FWD         Burnley
# 769                        zian_flemming      FWD         Burnley
# 28                        alexander_isak      FWD       Liverpool
# 108                        callum_wilson      FWD        West Ham
# 393                        junior_kroupi      FWD     Bournemouth
# 747                        wilson_isidor      FWD      Sunderland
# 153                        danny_welbeck      FWD        Brighton
# 386                       joshua_zirkzee      FWD         Man Utd
# 506                          mateus_mane      FWD          Wolves
# 118                charalampos_kostoulas      FWD        Brighton
# 80                        benjamin_sesko      FWD         Man Utd
# 703                       tolu_arokodare      FWD          Wolves
# 445                           liam_delap      FWD         Chelsea
# 576     norberto_bercique_gomes_betuncal      FWD         Everton
# 484                        marc_guiu_paz      FWD         Chelsea
# 129                     christantus_uche      FWD  Crystal Palace
# 461                         lukas_nmecha      FWD           Leeds
# 757                          yoane_wissa      FWD       Newcastle
# 240            gabriel_fernando_de_jesus      FWD         Arsenal
# 202                            enes_unal      FWD     Bournemouth
# 372                     jonah_kusi_asare      FWD          Fulham
# 686                      stefanos_tzimas      FWD        Brighton
# 365                           joel_piroe      FWD           Leeds
# 691                        taiwo_awoniyi      FWD   Nott'm Forest
# 61                     arnaud_kalimuendo      FWD   Nott'm Forest
# 768                    zepiqueno_redmond      FWD     Aston Villa
# 400                          kai_havertz      FWD         Arsenal
# 335                         jayden_danns      FWD       Liverpool
# 157                 darwin_nunez_ribeiro      FWD       Liverpool
# 266                           harry_gray      FWD           Leeds
#
#      ewma_total_points  predicted_points     owner
# 209              11.25          5.344560      Doug
# 176               9.25          4.976422      Dave
# 274               9.00          4.528037      Dave
# 329               5.75          4.309584     Lucas
# 587               6.25          4.082663      Rory
# 281               3.75          3.868405  no_owner
# 565               5.00          3.836926    Marcus
# 615               3.50          3.529393     Lucas
# 352               2.75          3.528216      Will
# 613               2.00          3.274441  no_owner
# 696               2.75          3.044617  no_owner
# 627               3.50          3.014176      Rory
# 377               1.25          2.990288  no_owner
# 283               1.75          2.968742    Marcus
# 233               2.75          2.935766      Will
# 339               2.00          2.879545      Will
# 185               3.25          2.634021  no_owner
# 96                1.50          2.519043  no_owner
# 59                3.00          2.466092  no_owner
# 731               2.25          2.348759      Doug
# 468               1.25          2.105718  no_owner
# 769               2.00          1.967988  no_owner
# 28                2.50          1.862765      Doug
# 108               2.00          1.762473  no_owner
# 393               2.00          1.725313  no_owner
# 747               0.75          1.488719  no_owner
# 153               1.00          1.485367     Lucas
# 386               1.00          1.426742      Rory
# 506               1.75          1.401590  no_owner
# 118               1.00          1.354752  no_owner
# 80                1.50          1.335900    Marcus
# 703               2.50          1.319172  no_owner
# 445               0.75          1.252946  no_owner
# 576               1.00          1.152997  no_owner
# 484               0.25          1.113392  no_owner
# 129               1.50          1.075430  no_owner
# 461               0.50          1.050457  no_owner
# 757               0.50          0.894429      Dave
# 240               0.50          0.817657  no_owner
# 202               0.50          0.815280  no_owner
# 372               0.50          0.743569  no_owner
# 686               0.25          0.635561  no_owner
# 365               0.75          0.617258  no_owner
# 691               0.25          0.598120  no_owner
# 61                0.25          0.504077  no_owner
# 768               0.00          0.490844  no_owner
# 400               0.00          0.482170  no_owner
# 335               0.00          0.480343  no_owner
# 157               0.00          0.480343  no_owner
# 266               0.00          0.475024  no_owner

# %%
a, b = get_best_11(df_sorted.query('owner=="Doug" and ~full_name.str.contains("reilly")'))
b
# Out:
#                            full_name position            team  \
# 9                     erling_haaland      FWD        Man City
# 4   matheus_santos_carneiro_da_cunha      MID         Man Utd
# 5                         phil_foden      MID        Man City
# 6                   pedro_lomba_neto      MID         Chelsea
# 7                 dominik_szoboszlai      MID       Liverpool
# 0                    jordan_pickford       GK         Everton
# 8                     yankuba_minteh      MID        Brighton
# 1              marc_cucurella_saseta      DEF         Chelsea
# 2                 jan_paul_van_hecke      DEF        Brighton
# 10                   viktor_gyokeres      FWD         Arsenal
# 3                     chris_richards      DEF  Crystal Palace
#
#     ewma_total_points  predicted_points owner
# 9               11.25          5.344560  Doug
# 4                6.25          5.122285  Doug
# 5               10.75          4.780739  Doug
# 6                4.00          3.899096  Doug
# 7                3.50          3.789567  Doug
# 0                4.25          3.403999  Doug
# 8                2.50          3.332058  Doug
# 1                3.50          2.679898  Doug
# 2                4.50          2.379120  Doug
# 10               2.25          2.348759  Doug
# 3                4.00          2.332071  Doug

# %%
rory_df = df_sorted.query('owner in ["no_owner", "Rory"]')
rory_df.query('position=="DEF"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                 full_name position            team  ewma_total_points  \
# 609        piero_hincapie      DEF         Arsenal               6.25
# 716       trevoh_chalobah      DEF         Chelsea               6.00
# 523       maxence_lacroix      DEF  Crystal Palace               3.00
# 486   marcos_senesi_baron      DEF     Bournemouth               3.25
# 532      micky_van_de_ven      DEF           Spurs               1.75
# 560         neco_williams      DEF   Nott'm Forest               4.50
# 173  diogo_dalot_teixeira      DEF         Man Utd               5.50
# 589         omar_alderete      DEF      Sunderland               4.50
# 310          jake_o'brien      DEF         Everton               4.25
# 476            malo_gusto      DEF         Chelsea               6.25
# 598        pascal_struijk      DEF           Leeds               2.50
# 149        daniel_ballard      DEF      Sunderland               5.50
# 241   gabriel_gudmundsson      DEF           Leeds               2.00
# 605   pedro_porro_sauceda      DEF           Spurs               1.75
# 139       cristian_romero      DEF           Spurs               6.00
# 23   alex_jimenez_sanchez      DEF     Bournemouth               3.75
# 276           ian_maatsen      DEF     Aston Villa               1.50
# 733     vitalii_mykolenko      DEF         Everton               3.00
# 309            jaka_bijol      DEF           Leeds               5.00
# 334          jayden_bogle      DEF           Leeds               3.25
#
#      predicted_points     owner
# 609          2.745179      Rory
# 716          2.691220      Rory
# 523          2.282040      Rory
# 486          2.219593      Rory
# 532          1.892579      Rory
# 560          3.096635  no_owner
# 173          3.061806  no_owner
# 589          2.917365  no_owner
# 310          2.790009  no_owner
# 476          2.738032  no_owner
# 598          2.719165  no_owner
# 149          2.685232  no_owner
# 241          2.682300  no_owner
# 605          2.662768  no_owner
# 139          2.629890  no_owner
# 23           2.611654  no_owner
# 276          2.604183  no_owner
# 733          2.575284  no_owner
# 309          2.528916  no_owner
# 334          2.520520  no_owner

# %% [markdown]
# # Random stuff

# %%
sns.kdeplot(data=df_sorted, x='predicted_points', hue='position')
# Out:
# <Axes: xlabel='predicted_points', ylabel='Density'>

# %%
check_pred_vs_avg = df_sorted.melt(id_vars=['full_name', 'position'], value_vars=['predicted_points', 'ewma_total_points'])
sns.kdeplot(data=check_pred_vs_avg.query('position=="DEF"'), x='value', hue='variable')
# Out:
# <Axes: xlabel='value', ylabel='Density'>

# %%
a, b, = get_best_11(df_sorted)
b
# Out:
#                            full_name position           team  \
# 9                     erling_haaland      FWD       Man City
# 4             bruno_borges_fernandes      MID        Man Utd
# 5   matheus_santos_carneiro_da_cunha      MID        Man Utd
# 10             dominic_calvert_lewin      FWD          Leeds
# 6                      morgan_rogers      MID    Aston Villa
# 7                         phil_foden      MID       Man City
# 8                    antoine_semenyo      MID    Bournemouth
# 0                        robin_roefs       GK     Sunderland
# 1                      matheus_nunes      DEF       Man City
# 2                      neco_williams      DEF  Nott'm Forest
# 3                     josko_gvardiol      DEF       Man City
#
#     ewma_total_points  predicted_points     owner
# 9               11.25          5.344560      Doug
# 4                9.00          5.157882      Will
# 5                6.25          5.122285      Doug
# 10               9.25          4.976422      Dave
# 6                9.50          4.801185    Marcus
# 7               10.75          4.780739      Doug
# 8                5.75          4.743683      Will
# 0                5.00          3.492412      Rory
# 1                6.75          3.305812     Lucas
# 2                4.50          3.096635  no_owner
# 3                6.50          3.076806      Dave

# %%
owner_dict = get_owner_dict()
b['owner'] = b['owner'].map(owner_dict)

# %%
b = b.sort_values('position', key=lambda s: s.apply(['GK', 'DEF', 'MID', 'FWD'].index), ignore_index=True)
b[['full_name', 'position', 'team', 'owner']]
# Out:
#                            full_name position           team owner
# 0                        robin_roefs       GK     Sunderland   NaN
# 1                     josko_gvardiol      DEF       Man City   NaN
# 2                      neco_williams      DEF  Nott'm Forest   NaN
# 3                      matheus_nunes      DEF       Man City   NaN
# 4                         phil_foden      MID       Man City   NaN
# 5             bruno_borges_fernandes      MID        Man Utd   NaN
# 6                      morgan_rogers      MID    Aston Villa   NaN
# 7   matheus_santos_carneiro_da_cunha      MID        Man Utd   NaN
# 8                    antoine_semenyo      MID    Bournemouth   NaN
# 9              dominic_calvert_lewin      FWD          Leeds   NaN
# 10                    erling_haaland      FWD       Man City   NaN

# %%
df_sorted.query('owner!="no_owner"').sort_values('predicted_points').head(40)
# Out:
#                         full_name position            team  ewma_total_points  \
# 239  gabriel_dos_santos_magalhaes      DEF         Arsenal               0.00
# 545         moises_caicedo_corozo      MID         Chelsea               0.75
# 757                   yoane_wissa      FWD       Newcastle               0.50
# 80                 benjamin_sesko      FWD         Man Utd               1.50
# 152            daniel_munoz_mejia      DEF  Crystal Palace               3.50
# 386                joshua_zirkzee      FWD         Man Utd               1.00
# 153                 danny_welbeck      FWD        Brighton               1.00
# 745                william_saliba      DEF         Arsenal               2.00
# 270                 harvey_barnes      MID       Newcastle               1.25
# 199      emiliano_martinez_romero       GK     Aston Villa               1.75
# 28                 alexander_isak      FWD       Liverpool               2.50
# 532              micky_van_de_ven      DEF           Spurs               1.75
# 530                 michael_keane      DEF         Everton               3.50
# 474                  malick_thiaw      DEF       Newcastle               1.75
# 486           marcos_senesi_baron      DEF     Bournemouth               3.25
# 626            riccardo_calafiori      DEF         Arsenal               3.50
# 68                 bafode_diakite      DEF     Bournemouth               3.00
# 543                 mohamed_salah      MID       Liverpool               2.00
# 523               maxence_lacroix      DEF  Crystal Palace               3.00
# 349              joachim_andersen      DEF          Fulham               2.50
# 219              ezri_konsa_ngoyo      DEF     Aston Villa               1.50
# 126                chris_richards      DEF  Crystal Palace               4.00
# 429              leandro_trossard      MID         Arsenal               2.50
# 725               tyrick_mitchell      DEF  Crystal Palace               2.25
# 731               viktor_gyokeres      FWD         Arsenal               2.25
# 618                   reece_james      DEF         Chelsea               4.75
# 327            jan_paul_van_hecke      DEF        Brighton               4.50
# 345                   jeremy_doku      MID        Man City               2.75
# 135                   cole_palmer      MID         Chelsea               3.25
# 394                jurrien_timber      DEF         Arsenal               3.00
# 279               ibrahima_konate      DEF       Liverpool               3.75
# 14                adrien_truffert      DEF     Bournemouth               3.75
# 732               virgil_van_dijk      DEF       Liverpool               3.50
# 410                  kevin_schade      MID       Brentford               1.25
# 482         marc_cucurella_saseta      DEF         Chelsea               3.50
# 322               james_tarkowski      DEF         Everton               5.75
# 716               trevoh_chalobah      DEF         Chelsea               6.00
# 609                piero_hincapie      DEF         Arsenal               6.25
# 568                 nico_o'reilly      DEF        Man City               4.50
# 519                    matty_cash      DEF     Aston Villa               3.75
#
#      predicted_points   owner
# 239          0.397614    Will
# 545          0.890071    Rory
# 757          0.894429    Dave
# 80           1.335900  Marcus
# 152          1.352567    Will
# 386          1.426742    Rory
# 153          1.485367   Lucas
# 745          1.535951   Lucas
# 270          1.638665    Dave
# 199          1.694231   Lucas
# 28           1.862765    Doug
# 532          1.892579    Rory
# 530          1.954198    Dave
# 474          2.193302    Dave
# 486          2.219593    Rory
# 626          2.241612   Lucas
# 68           2.248812    Will
# 543          2.259829  Marcus
# 523          2.282040    Rory
# 349          2.291996   Lucas
# 219          2.332070    Doug
# 126          2.332071    Doug
# 429          2.342569    Dave
# 725          2.343582    Dave
# 731          2.348759    Doug
# 618          2.373671    Will
# 327          2.379120    Doug
# 345          2.387181   Lucas
# 135          2.452526    Rory
# 394          2.460589    Will
# 279          2.560038   Lucas
# 14           2.618546  Marcus
# 732          2.644299  Marcus
# 410          2.648319   Lucas
# 482          2.679898    Doug
# 322          2.690387  Marcus
# 716          2.691220    Rory
# 609          2.745179    Rory
# 568          2.761354    Doug
# 519          2.803289    Dave

# %%
pred_points
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pred_points
#
# NameError: name 'pred_points' is not defined

# %%
lw_results = pd.DataFrame({'User': ['Doug', 'Lucas', 'Will', 'Marcus', 'Dave', 'Rory'],
              'Predicted points': pred_points,
              'Actual points': [33, 13, 39, 36, 30, 42]}, 
              )

# %%
lw_results.sort_values('Actual points', ascending=False)
# Out:
#      User  Predicted points  Actual points
# 5    Rory             33.34             42
# 2    Will             40.75             39
# 3  Marcus             32.91             36
# 0    Doug             39.28             33
# 4    Dave             36.83             30
# 1   Lucas             36.82             13

# %%
plt.figure(figsize=(3,3))
ax = sns.scatterplot(data=lw_results, x='Predicted points', y='Actual points', hue='User', s=100)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# # Figuring out how the model did last week

# %%
gw6 = pd.read_csv('predicted_gw6_simple.csv')
gw6
# Out:
#                 full_name position         team  ewma_total_points  \
# 0         aaron_anselmino      DEF      Chelsea             0.0000
# 1            aaron_hickey      DEF    Brentford             0.3129
# 2          aaron_ramsdale       GK    Newcastle             0.0000
# 3            aaron_ramsey      MID      Burnley             0.0000
# 4       aaron_wan_bissaka      DEF     West Ham             0.2401
# ..                    ...      ...          ...                ...
# 736  zain_silcott_duberry      MID  Bournemouth             0.0000
# 737           zak_johnson      DEF   Sunderland             0.0000
# 738          zeki_amdouni      FWD      Burnley             0.0000
# 739     zepiqueno_redmond      FWD  Aston Villa             0.0000
# 740         zian_flemming      FWD      Burnley             0.6430
#
#      predicted_points  owner
# 0            0.108120    NaN
# 1            0.214515    NaN
# 2            0.061611    NaN
# 3            0.178312    NaN
# 4            0.729524    NaN
# ..                ...    ...
# 736          0.263160    NaN
# 737          0.122112    NaN
# 738          0.067864    NaN
# 739          0.236978    NaN
# 740          0.862229    NaN
#
# [741 rows x 6 columns]

# %%
gw7 = pd.read_csv('predicted_gw7.csv')
gw6_7_merged = gw6.merge(gw7[['full_name', 'total_points']], on='full_name')

# %%
import numpy as np
import scipy
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error

# %%
x = gw6_7_merged['predicted_points']
y = gw6_7_merged['total_points']
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print(r_value)
# Out:
# 0.5529193700354283

# %%
sns.scatterplot(data=gw6_7_merged, x='predicted_points', y='total_points', hue='position')
x_range = np.linspace(0,6, 100)
y_range = slope*x_range + intercept
# plt.plot(x_range, y_range, color='black')

# %%
sns.scatterplot(data=gw6_7_merged, x='ewma_total_points', y='total_points', hue='position')
# Out:
# <Axes: xlabel='ewma_total_points', ylabel='total_points'>

# %%
root_mean_squared_error(x, y)
# Out:
# 1.8981549268092774
