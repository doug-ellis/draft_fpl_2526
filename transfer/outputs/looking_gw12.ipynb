# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from other_funcs import *

# %%
df = pd.read_csv('predicted_gw12_simple.csv')
df_sorted = df.sort_values('predicted_points', ascending=False)

# %%
df_sorted.query('owner==88376.0')
# Out:
#               full_name position            team  ewma_total_points  \
# 207      erling_haaland      FWD        Man City               8.00
# 592    pedro_lomba_neto      MID         Chelsea               8.00
# 595          phil_foden      MID        Man City               2.75
# 733      yankuba_minteh      MID        Brighton               4.75
# 177  dominik_szoboszlai      MID       Liverpool               4.25
# 182        eberechi_eze      MID         Arsenal               4.75
# 556       nico_o'reilly      DEF        Man City               7.75
# 369     jordan_pickford       GK         Everton               3.00
# 714     viktor_gyokeres      FWD         Arsenal               2.75
# 566       nordi_mukiele      DEF      Sunderland               6.00
# 179      dorde_petrovic       GK     Bournemouth               3.25
# 443         lucas_digne      DEF     Aston Villa               5.25
# 356           joe_rodon      DEF           Leeds               4.00
# 124      chris_richards      DEF  Crystal Palace               4.75
# 28       alexander_isak      FWD       Liverpool               0.50
#
#      predicted_points    owner
# 207          5.169894  88376.0
# 592          4.295730  88376.0
# 595          4.039789  88376.0
# 733          3.730170  88376.0
# 177          3.464095  88376.0
# 182          3.156328  88376.0
# 556          3.083409  88376.0
# 369          2.980570  88376.0
# 714          2.925015  88376.0
# 566          2.868498  88376.0
# 179          2.844978  88376.0
# 443          2.804444  88376.0
# 356          2.639608  88376.0
# 124          2.554662  88376.0
# 28           1.054382  88376.0

# %%
owner_dict = get_owner_dict()
df_sorted['owner'] = df_sorted['owner'].map(owner_dict)
df_sorted['owner'] = df_sorted['owner'].fillna('no_owner')

# %%
transfer_df = df_sorted.query('owner in ["no_owner", "Doug"]')

# %%
transfer_df.query('position=="GK"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                       full_name position           team  ewma_total_points  \
# 369             jordan_pickford       GK        Everton               3.00
# 179              dorde_petrovic       GK    Bournemouth               3.25
# 197    emiliano_martinez_romero       GK    Aston Villa               6.25
# 69              bart_verbruggen       GK       Brighton               3.75
# 83                   bernd_leno       GK         Fulham               3.50
# 486             martin_dubravka       GK        Burnley               3.75
# 245        giorgi_mamardashvili       GK      Liverpool               4.25
# 509                   matz_sels       GK  Nott'm Forest               2.00
# 32              alphonse_areola       GK       West Ham               2.25
# 642               sam_johnstone       GK         Wolves               1.75
# 444         lucas_estella_perri       GK          Leeds               1.25
# 396                 karl_darlow       GK          Leeds               0.25
# 694               tommy_setford       GK        Arsenal               0.00
# 401  kepa_arrizabalaga_revuelta       GK        Arsenal               0.00
# 397                   karl_hein       GK        Arsenal               0.00
# 228             filip_marschall       GK    Aston Villa               0.00
# 227             filip_jorgensen       GK        Chelsea               0.00
# 506                 matthew_cox       GK      Brentford               0.00
# 522                mike_penders       GK        Chelsea               0.00
# 475                 marco_bizot       GK    Aston Villa               0.00
#
#      predicted_points     owner
# 369          2.980570      Doug
# 179          2.844978      Doug
# 197          3.392015  no_owner
# 69           3.354649  no_owner
# 83           3.062532  no_owner
# 486          2.965738  no_owner
# 245          2.947999  no_owner
# 509          2.895752  no_owner
# 32           2.880644  no_owner
# 642          2.686622  no_owner
# 444          2.095031  no_owner
# 396          0.890703  no_owner
# 694          0.261584  no_owner
# 401          0.261584  no_owner
# 397          0.261584  no_owner
# 228          0.253186  no_owner
# 227          0.253186  no_owner
# 506          0.253186  no_owner
# 522          0.253186  no_owner
# 475          0.253186  no_owner

# %%
transfer_df.query('position=="DEF"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                full_name position            team  ewma_total_points  \
# 556        nico_o'reilly      DEF        Man City               7.75
# 566        nordi_mukiele      DEF      Sunderland               6.00
# 443          lucas_digne      DEF     Aston Villa               5.25
# 356            joe_rodon      DEF           Leeds               4.00
# 124       chris_richards      DEF  Crystal Palace               4.75
# 518       michael_kayode      DEF       Brentford               3.75
# 147       daniel_ballard      DEF      Sunderland               6.50
# 323   jan_paul_van_hecke      DEF        Brighton               4.50
# 697            trai_hume      DEF      Sunderland               3.75
# 466           malo_gusto      DEF         Chelsea               6.00
# 599  quilindschy_hartman      DEF         Burnley               3.75
# 226       ferdi_kadioglu      DEF        Brighton               3.25
# 217     ezri_konsa_ngoyo      DEF     Aston Villa               4.25
# 416          kyle_walker      DEF         Burnley               4.50
# 659    sepp_van_den_berg      DEF       Brentford               3.50
# 318      james_tarkowski      DEF         Everton               2.75
# 542       nathan_collins      DEF       Brentford               3.50
# 432           lewis_dunk      DEF        Brighton               3.50
# 590           pau_torres      DEF     Aston Villa               4.25
# 238  gabriel_gudmundsson      DEF           Leeds               1.00
#
#      predicted_points     owner
# 556          3.083409      Doug
# 566          2.868498      Doug
# 443          2.804444      Doug
# 356          2.639608      Doug
# 124          2.554662      Doug
# 518          3.383525  no_owner
# 147          3.186091  no_owner
# 323          2.848799  no_owner
# 697          2.823090  no_owner
# 466          2.779380  no_owner
# 599          2.672527  no_owner
# 226          2.649008  no_owner
# 217          2.597794  no_owner
# 416          2.569808  no_owner
# 659          2.546735  no_owner
# 318          2.532153  no_owner
# 542          2.515269  no_owner
# 432          2.506311  no_owner
# 590          2.494761  no_owner
# 238          2.474239  no_owner

# %%
transfer_df.query('position=="MID"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                            full_name position           team  \
# 592                 pedro_lomba_neto      MID        Chelsea
# 595                       phil_foden      MID       Man City
# 733                   yankuba_minteh      MID       Brighton
# 177               dominik_szoboszlai      MID      Liverpool
# 182                     eberechi_eze      MID        Arsenal
# 404                     kevin_schade      MID      Brentford
# 145                   dango_ouattara      MID      Brentford
# 20       alejandro_garnacho_ferreyra      MID        Chelsea
# 168             diego_gomez_amarilla      MID       Brighton
# 97   bruno_guimaraes_rodriguez_moura      MID      Newcastle
# 341                      jeremy_doku      MID       Man City
# 480                 marcus_tavernier      MID    Bournemouth
# 22                        alex_iwobi      MID         Fulham
# 93                  brenden_aaronson      MID          Leeds
# 191                  elliot_anderson      MID  Nott'm Forest
# 526                 mikkel_damsgaard      MID      Brentford
# 501                     mats_wieffer      MID       Brighton
# 248                     granit_xhaka      MID     Sunderland
# 114         carlos_henrique_casimiro      MID        Man Utd
# 34                       amad_diallo      MID        Man Utd
#
#      ewma_total_points  predicted_points     owner
# 592               8.00          4.295730      Doug
# 595               2.75          4.039789      Doug
# 733               4.75          3.730170      Doug
# 177               4.25          3.464095      Doug
# 182               4.75          3.156328      Doug
# 404               5.50          4.212882  no_owner
# 145               5.00          4.080357  no_owner
# 20                5.25          3.884849  no_owner
# 168               5.25          3.877208  no_owner
# 97                5.00          3.793227  no_owner
# 341               3.75          3.699802  no_owner
# 480               5.00          3.668074  no_owner
# 22                2.50          3.605971  no_owner
# 93                5.50          3.585079  no_owner
# 191               4.75          3.459478  no_owner
# 526               3.50          3.357144  no_owner
# 501               6.00          3.235870  no_owner
# 248               5.00          3.190881  no_owner
# 114               8.00          3.180284  no_owner
# 34                5.75          3.153498  no_owner

# %%
transfer_df.query('position=="FWD"').sort_values(['owner', 'predicted_points'], ascending=[True, False]).head(20)
# Out:
#                             full_name position            team  \
# 207                    erling_haaland      FWD        Man City
# 714                   viktor_gyokeres      FWD         Arsenal
# 28                     alexander_isak      FWD       Liverpool
# 751                     zian_flemming      FWD         Burnley
# 729                     wilson_isidor      FWD      Sunderland
# 174             dominic_calvert_lewin      FWD           Leeds
# 107                     callum_wilson      FWD        West Ham
# 277         igor_jesus_maciel_da_cruz      FWD   Nott'm Forest
# 601                 randal_kolo_muani      FWD           Spurs
# 564  norberto_bercique_gomes_betuncal      FWD         Everton
# 453                      lukas_nmecha      FWD           Leeds
# 674                     taiwo_awoniyi      FWD   Nott'm Forest
# 679                     thierno_barry      FWD         Everton
# 474                     marc_guiu_paz      FWD         Chelsea
# 95                      brian_brobbey      FWD      Sunderland
# 495                       mateus_mane      FWD          Wolves
# 117             charalampos_kostoulas      FWD        Brighton
# 726                     william_osula      FWD       Newcastle
# 183                     eddie_nketiah      FWD  Crystal Palace
# 437                        liam_delap      FWD         Chelsea
#
#      ewma_total_points  predicted_points     owner
# 207               8.00          5.169894      Doug
# 714               2.75          2.925015      Doug
# 28                0.50          1.054382      Doug
# 751               5.25          4.102332  no_owner
# 729               3.25          3.232127  no_owner
# 174               1.75          2.646304  no_owner
# 107               2.75          2.588838  no_owner
# 277               2.00          2.435875  no_owner
# 601               1.50          2.195892  no_owner
# 564               1.50          2.032875  no_owner
# 453               2.75          1.858736  no_owner
# 674               1.00          1.784183  no_owner
# 679               1.00          1.780429  no_owner
# 474               1.00          1.417188  no_owner
# 95                2.50          1.372326  no_owner
# 495               1.00          1.227296  no_owner
# 117               2.00          1.169820  no_owner
# 726               1.50          1.091036  no_owner
# 183               0.50          1.086604  no_owner
# 437               0.50          1.081817  no_owner

# %%
df_sorted.query('position=="MID"').head(50)
# Out:
#                                              full_name position  \
# 99                                        bryan_mbeumo      MID
# 100                                        bukayo_saka      MID
# 531                                      mohamed_salah      MID
# 423                                   leandro_trossard      MID
# 592                                   pedro_lomba_neto      MID
# 404                                       kevin_schade      MID
# 145                                     dango_ouattara      MID
# 96                              bruno_borges_fernandes      MID
# 595                                         phil_foden      MID
# 534                                 morgan_gibbs_white      MID
# 20                         alejandro_garnacho_ferreyra      MID
# 168                               diego_gomez_amarilla      MID
# 162                                        declan_rice      MID
# 97                     bruno_guimaraes_rodriguez_moura      MID
# 733                                     yankuba_minteh      MID
# 341                                        jeremy_doku      MID
# 480                                   marcus_tavernier      MID
# 204                                     enzo_fernandez      MID
# 22                                          alex_iwobi      MID
# 93                                    brenden_aaronson      MID
# 132                                         cody_gakpo      MID
# 177                                 dominik_szoboszlai      MID
# 191                                    elliot_anderson      MID
# 281                                      iliman_ndiaye      MID
# 299                                       jacob_murphy      MID
# 526                                   mikkel_damsgaard      MID
# 51                                     antoine_semenyo      MID
# 498                   matheus_santos_carneiro_da_cunha      MID
# 501                                       mats_wieffer      MID
# 446                     lucas_tolentino_coelho_de_lima      MID
# 248                                       granit_xhaka      MID
# 114                           carlos_henrique_casimiro      MID
# 182                                       eberechi_eze      MID
# 34                                         amad_diallo      MID
# 288                                       ismaila_sarr      MID
# 276                                 idrissa_gana_gueye      MID
# 484                                   marshall_munetsi      MID
# 535                                      morgan_rogers      MID
# 375                                        josh_cullen      MID
# 693                                       tomas_soucek      MID
# 637                                     ryan_sessegnon      MID
# 489                            martin_zubimendi_ibanez      MID
# 734                                        yasin_ayari      MID
# 408                              kiernan_dewsbury_hall      MID
# 346  joao_maria_lobo_alves_palhares_costa_palhinha_...      MID
# 428                                   lesley_ugochukwu      MID
# 229                      florentino_ibrain_morris_luis      MID
# 138                              crysencio_summerville      MID
# 702                                        tyler_adams      MID
# 647                                       sander_berge      MID
#
#                team  ewma_total_points  predicted_points     owner
# 99          Man Utd               8.25          4.807860    Marcus
# 100         Arsenal               6.25          4.790382      Will
# 531       Liverpool               5.00          4.596254    Marcus
# 423         Arsenal               7.00          4.334945      Dave
# 592         Chelsea               8.00          4.295730      Doug
# 404       Brentford               5.50          4.212882  no_owner
# 145       Brentford               5.00          4.080357  no_owner
# 96          Man Utd               5.50          4.054090      Will
# 595        Man City               2.75          4.039789      Doug
# 534   Nott'm Forest               5.50          4.023122     Lucas
# 20          Chelsea               5.25          3.884849  no_owner
# 168        Brighton               5.25          3.877208  no_owner
# 162         Arsenal               6.25          3.808801      Rory
# 97        Newcastle               5.00          3.793227  no_owner
# 733        Brighton               4.75          3.730170      Doug
# 341        Man City               3.75          3.699802  no_owner
# 480     Bournemouth               5.00          3.668074  no_owner
# 204         Chelsea               1.75          3.668008     Lucas
# 22           Fulham               2.50          3.605971  no_owner
# 93            Leeds               5.50          3.585079  no_owner
# 132       Liverpool               3.25          3.580710     Lucas
# 177       Liverpool               4.25          3.464095      Doug
# 191   Nott'm Forest               4.75          3.459478  no_owner
# 281         Everton               4.50          3.410337      Will
# 299       Newcastle               4.75          3.363930      Dave
# 526       Brentford               3.50          3.357144  no_owner
# 51      Bournemouth               2.25          3.327406      Will
# 498         Man Utd               4.25          3.307333     Lucas
# 501        Brighton               6.00          3.235870  no_owner
# 446        West Ham               4.00          3.204597      Will
# 248      Sunderland               5.00          3.190881  no_owner
# 114         Man Utd               8.00          3.180284  no_owner
# 182         Arsenal               4.75          3.156328      Doug
# 34          Man Utd               5.75          3.153498  no_owner
# 288  Crystal Palace               2.50          3.125605      Dave
# 276         Everton               4.50          3.120117  no_owner
# 484          Wolves               4.00          3.119825  no_owner
# 535     Aston Villa               3.25          3.091960    Marcus
# 375         Burnley               4.00          3.090497  no_owner
# 693        West Ham               5.50          3.067725  no_owner
# 637          Fulham               6.00          3.063080  no_owner
# 489         Arsenal               4.00          3.057937  no_owner
# 734        Brighton               2.25          3.027769  no_owner
# 408         Everton               3.75          3.025156  no_owner
# 346           Spurs               5.25          2.935586  no_owner
# 428         Burnley               4.75          2.927316  no_owner
# 229         Burnley               4.00          2.900485  no_owner
# 138        West Ham               2.25          2.884862  no_owner
# 702     Bournemouth               4.75          2.879555  no_owner
# 647          Fulham               2.75          2.871841  no_owner

# %%
a, b = get_best_11(df_sorted.query('owner=="Doug" and ~full_name.str.contains("reilly")'))
b
# Out:
#              full_name position         team  ewma_total_points  \
# 9       erling_haaland      FWD     Man City               8.00
# 4     pedro_lomba_neto      MID      Chelsea               8.00
# 5           phil_foden      MID     Man City               2.75
# 6       yankuba_minteh      MID     Brighton               4.75
# 7   dominik_szoboszlai      MID    Liverpool               4.25
# 8         eberechi_eze      MID      Arsenal               4.75
# 0      jordan_pickford       GK      Everton               3.00
# 10     viktor_gyokeres      FWD      Arsenal               2.75
# 1        nordi_mukiele      DEF   Sunderland               6.00
# 2          lucas_digne      DEF  Aston Villa               5.25
# 3            joe_rodon      DEF        Leeds               4.00
#
#     predicted_points owner
# 9           5.169894  Doug
# 4           4.295730  Doug
# 5           4.039789  Doug
# 6           3.730170  Doug
# 7           3.464095  Doug
# 8           3.156328  Doug
# 0           2.980570  Doug
# 10          2.925015  Doug
# 1           2.868498  Doug
# 2           2.804444  Doug
# 3           2.639608  Doug

# %% [markdown]
# # Random stuff

# %%
a, b, = get_best_11(df_sorted)
b
# Out:
#                        full_name position            team  ewma_total_points  \
# 8                 erling_haaland      FWD        Man City               8.00
# 9                  danny_welbeck      FWD        Brighton               6.75
# 4                   bryan_mbeumo      MID         Man Utd               8.25
# 5                    bukayo_saka      MID         Arsenal               6.25
# 10          jean_philippe_mateta      FWD  Crystal Palace               7.50
# 6                  mohamed_salah      MID       Liverpool               5.00
# 7               leandro_trossard      MID         Arsenal               7.00
# 0              david_raya_martin       GK         Arsenal               4.75
# 1                 michael_kayode      DEF       Brentford               3.75
# 2   gabriel_dos_santos_magalhaes      DEF         Arsenal               8.50
# 3          marc_cucurella_saseta      DEF         Chelsea               5.50
#
#     predicted_points     owner
# 8           5.169894      Doug
# 9           5.029058     Lucas
# 4           4.807860    Marcus
# 5           4.790382      Will
# 10          4.776781      Will
# 6           4.596254    Marcus
# 7           4.334945      Dave
# 0           3.658521      Dave
# 1           3.383525  no_owner
# 2           3.314333      Will
# 3           3.294637      Will

# %%
owner_dict = get_owner_dict()
b['owner'] = b['owner'].map(owner_dict)

# %%
b = b.sort_values('position', key=lambda s: s.apply(['GK', 'DEF', 'MID', 'FWD'].index), ignore_index=True)
b[['full_name', 'position', 'team', 'owner']]
# Out:
#                        full_name position            team owner
# 0              david_raya_martin       GK         Arsenal   NaN
# 1          marc_cucurella_saseta      DEF         Chelsea   NaN
# 2   gabriel_dos_santos_magalhaes      DEF         Arsenal   NaN
# 3                 michael_kayode      DEF       Brentford   NaN
# 4               leandro_trossard      MID         Arsenal   NaN
# 5                    bukayo_saka      MID         Arsenal   NaN
# 6                  mohamed_salah      MID       Liverpool   NaN
# 7                   bryan_mbeumo      MID         Man Utd   NaN
# 8           jean_philippe_mateta      FWD  Crystal Palace   NaN
# 9                 erling_haaland      FWD        Man City   NaN
# 10                 danny_welbeck      FWD        Brighton   NaN

# %%
df_sorted.query('owner!="no_owner"').sort_values('predicted_points').head(40)
# Out:
#                                full_name position            team  \
# 31                        alisson_becker       GK       Liverpool
# 530                         mitoma_kaoru      MID        Brighton
# 487                      martin_odegaard      MID         Arsenal
# 133                          cole_palmer      MID         Chelsea
# 739                          yoane_wissa      FWD       Newcastle
# 28                        alexander_isak      FWD       Liverpool
# 68                        bafode_diakite      DEF     Bournemouth
# 231  francisco_evanilson_de_lima_barbosa      FWD     Bournemouth
# 387                        junior_kroupi      FWD     Bournemouth
# 524                   mikel_merino_zazon      MID         Arsenal
# 141                             dan_burn      DEF       Newcastle
# 381                       josko_gvardiol      DEF        Man City
# 536             murillo_costa_dos_santos      DEF   Nott'm Forest
# 49                        anthony_gordon      MID       Newcastle
# 635                     ryan_gravenberch      MID       Liverpool
# 476                  marcos_senesi_baron      DEF     Bournemouth
# 14                       adrien_truffert      DEF     Bournemouth
# 473                           marc_guehi      DEF  Crystal Palace
# 275                      ibrahima_konate      DEF       Liverpool
# 715                      virgil_van_dijk      DEF       Liverpool
# 727                       william_saliba      DEF         Arsenal
# 614               richarlison_de_andrade      FWD           Spurs
# 593                  pedro_porro_sauceda      DEF           Spurs
# 519                        michael_keane      DEF         Everton
# 270                         hugo_ekitike      FWD       Liverpool
# 79                        benjamin_sesko      FWD         Man Utd
# 124                       chris_richards      DEF  Crystal Palace
# 512                      maxence_lacroix      DEF  Crystal Palace
# 356                            joe_rodon      DEF           Leeds
# 303                       jaidon_anthony      MID         Burnley
# 293                        jack_grealish      MID         Everton
# 533                moises_caicedo_corozo      MID         Chelsea
# 708                      tyrick_mitchell      DEF  Crystal Palace
# 633     ruben_dos_santos_gato_alves_dias      DEF        Man City
# 552                            nick_pope       GK       Newcastle
# 699                      trevoh_chalobah      DEF         Chelsea
# 443                          lucas_digne      DEF     Aston Villa
# 521                     micky_van_de_ven      DEF           Spurs
# 179                       dorde_petrovic       GK     Bournemouth
# 575                        ollie_watkins      FWD     Aston Villa
#
#      ewma_total_points  predicted_points   owner
# 31                0.00          0.202803    Will
# 530               0.00          0.367508  Marcus
# 487               0.00          0.367508  Marcus
# 133               0.00          0.367508    Rory
# 739               0.00          0.450994    Dave
# 28                0.50          1.054382    Doug
# 68                1.00          1.171920    Rory
# 231               0.75          1.327437   Lucas
# 387               1.00          1.395160    Dave
# 524               2.00          1.731744   Lucas
# 141               1.25          1.777407    Dave
# 381               2.50          1.999665   Lucas
# 536               1.50          2.011835  Marcus
# 49                1.25          2.018694    Rory
# 635               3.75          2.132476    Rory
# 476               3.00          2.225240    Rory
# 14                3.25          2.346923  Marcus
# 473               4.50          2.386020  Marcus
# 275               3.75          2.388960   Lucas
# 715               3.00          2.390237  Marcus
# 727               3.50          2.412020   Lucas
# 614               3.00          2.437713    Rory
# 593               4.00          2.438874    Will
# 519               5.25          2.470878    Dave
# 270               1.50          2.494819   Lucas
# 79                2.00          2.512513    Will
# 124               4.75          2.554662    Doug
# 512               4.75          2.556998    Rory
# 356               4.00          2.639608    Doug
# 303               2.00          2.649669    Dave
# 293               1.50          2.663160    Dave
# 533               3.75          2.704775    Rory
# 708               5.00          2.716224    Dave
# 633               4.50          2.739515  Marcus
# 552               2.75          2.772236   Lucas
# 699               5.00          2.778473   Lucas
# 443               5.25          2.804444    Doug
# 521               6.50          2.824183    Rory
# 179               3.25          2.844978    Doug
# 575               1.75          2.846639    Rory

# %%
pred_points
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pred_points
#
# NameError: name 'pred_points' is not defined

# %%
lw_results = pd.DataFrame({'User': ['Doug', 'Lucas', 'Will', 'Marcus', 'Dave', 'Rory'],
              'Predicted points': pred_points,
              'Actual points': [33, 13, 39, 36, 30, 42]}, 
              )

# %%
lw_results.sort_values('Actual points', ascending=False)
# Out:
#      User  Predicted points  Actual points
# 5    Rory             33.34             42
# 2    Will             40.75             39
# 3  Marcus             32.91             36
# 0    Doug             39.28             33
# 4    Dave             36.83             30
# 1   Lucas             36.82             13

# %%
plt.figure(figsize=(3,3))
ax = sns.scatterplot(data=lw_results, x='Predicted points', y='Actual points', hue='User', s=100)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# # Figuring out how the model did last week

# %%
gw6 = pd.read_csv('predicted_gw6_simple.csv')
gw6
# Out:
#                 full_name position         team  ewma_total_points  \
# 0         aaron_anselmino      DEF      Chelsea             0.0000
# 1            aaron_hickey      DEF    Brentford             0.3129
# 2          aaron_ramsdale       GK    Newcastle             0.0000
# 3            aaron_ramsey      MID      Burnley             0.0000
# 4       aaron_wan_bissaka      DEF     West Ham             0.2401
# ..                    ...      ...          ...                ...
# 736  zain_silcott_duberry      MID  Bournemouth             0.0000
# 737           zak_johnson      DEF   Sunderland             0.0000
# 738          zeki_amdouni      FWD      Burnley             0.0000
# 739     zepiqueno_redmond      FWD  Aston Villa             0.0000
# 740         zian_flemming      FWD      Burnley             0.6430
#
#      predicted_points  owner
# 0            0.108120    NaN
# 1            0.214515    NaN
# 2            0.061611    NaN
# 3            0.178312    NaN
# 4            0.729524    NaN
# ..                ...    ...
# 736          0.263160    NaN
# 737          0.122112    NaN
# 738          0.067864    NaN
# 739          0.236978    NaN
# 740          0.862229    NaN
#
# [741 rows x 6 columns]

# %%
gw7 = pd.read_csv('predicted_gw7.csv')
gw6_7_merged = gw6.merge(gw7[['full_name', 'total_points']], on='full_name')

# %%
import numpy as np
import scipy
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error

# %%
x = gw6_7_merged['predicted_points']
y = gw6_7_merged['total_points']
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print(r_value)
# Out:
# 0.5529193700354283

# %%
sns.scatterplot(data=gw6_7_merged, x='predicted_points', y='total_points', hue='position')
x_range = np.linspace(0,6, 100)
y_range = slope*x_range + intercept
# plt.plot(x_range, y_range, color='black')

# %%
sns.scatterplot(data=gw6_7_merged, x='ewma_total_points', y='total_points', hue='position')
# Out:
# <Axes: xlabel='ewma_total_points', ylabel='total_points'>

# %%
root_mean_squared_error(x, y)
# Out:
# 1.8981549268092774
